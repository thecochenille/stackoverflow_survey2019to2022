# %% [markdown]
# Udacity Data Scientist Nanodegree Project 1: Working through the CRISP-DM process
# ===============
#
# # Introduction
# The CRISP-DM or cross-industry standard process for data mining process is an open process model that allows us to carry out data mining using defined and systematic steps. This method was proven to be efficient while using data to provide insight and offer solutions for businesses.
#
# This process comprises of six major phases that we will work through here:
# - Business Understanding
# - Data Understanding
# - Data Preparation
# - Modeling
# - Evaluation
# - Deployment
#
# In the case of the Udacity Project here, we had to select a dataset before starting the CRISP-DM process. I decided to work with the Stackoverflow surveys data from 2019 to 2022.

# %% [markdown]
# ## Business Understanding
# This include questions that a business is asking and needs solutions for.
# My three main business questions are:
#
# - What type of cloud platform do data scientist want to learn to use?
# - What coding languages are in demand in the data science world.
# -

# %%
## Data Understanding
### Looking at the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import display
# %matplotlib inline

df2022 = pd.read_csv('./survey_results_public2022.csv')

# %%
df2022.shape
# Out:
# (73268, 79)

# %% [markdown]
# In 2022, more than 73000 people answered the survey in Stackoverflow

# %%
#Let's take a look at the column headers
df2022.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'Blockchain', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity',
#        'Accessibility', 'MentalHealth', 'TBranch', 'ICorPM', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Frequency_1',
#        'Frequency_2', 'Frequency_3', 'TimeSearching', 'TimeAnswering',
#        'Onboarding', 'ProfessionalTech', 'TrueFalse_1', 'TrueFalse_2',
#        'TrueFalse_3', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
There were a lot of questions answered but for my three questions, I will keep only a few features.
Let's first look at how the force response look like. There are a few questions that requires answers, which can be found in the survey result schema file.
- MainBranch
- Country
- Currency
- TBranch

# %%
df2022['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   53507
# I am learning to code                                                             6309
# I am not primarily a developer, but I write code sometimes as part of my work     5794
# I code primarily as a hobby                                                       4865
# None of these                                                                     1497
# I used to be a developer by profession, but no longer am                          1296
# Name: MainBranch, dtype: int64

# %%
df2022['TBranch'].value_counts()
# Out:
# Yes    37200
# No     15470
# Name: TBranch, dtype: int64

# %%
df2022['TBranch'].isnull().sum()
# Out:
# 20598

# %%
### Countries that answered the survey

# %%
df2022['Country'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
We can see that the survey was answered in majority by four countries above 4000 people.

# %%
df2022['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
#subsetting USA data since I want to know what are the trends in the Us specifically, since this is where I am looking for a job

# %%
df2022_US=df2022[df2022['Country']=='United States of America']
df2022_US.shape
# Out:
# (13543, 76)

# %% [markdown]
# ## Question 1: What cloud platforms people want to learn?
# To answer this question, we will compare the platforms participants currently work on and the ones they wish to learn how to use.

# %%
#taking a quick look at 'PlatformHaveWorkedWith'
df2022_US['PlatformHaveWorkedWith'].dropna().unique().tolist()
# Out:
# ['Firebase;Microsoft Azure',
#  'AWS;Microsoft Azure',
#  'AWS',
#  'AWS;DigitalOcean;Heroku',
#  'Microsoft Azure',
#  'AWS;Managed Hosting;Microsoft Azure',
#  'AWS;Microsoft Azure;VMware',
#  'Firebase;Google Cloud;Heroku',
#  'Google Cloud;Microsoft Azure;VMware',
#  'AWS;Firebase;Google Cloud',
#  'AWS;Firebase;Google Cloud;Microsoft Azure',
#  'AWS;Google Cloud;Managed Hosting;VMware',
#  'AWS;Google Cloud',
#  'AWS;Managed Hosting',
#  'AWS;Google Cloud;IBM Cloud or Watson',
#  'AWS;Firebase;Google Cloud;Heroku',
#  'DigitalOcean;Microsoft Azure',
#  'Google Cloud',
#  'AWS;Google Cloud;Microsoft Azure',
#  'AWS;DigitalOcean',
#  'AWS;VMware',
#  'AWS;DigitalOcean;Linode',
#  'Google Cloud;Linode',
#  'Colocation;Microsoft Azure;VMware',
#  'Managed Hosting',
#  'VMware',
#  'AWS;Heroku',
#  'DigitalOcean',
#  'AWS;DigitalOcean;Microsoft Azure',
#  'IBM Cloud or Watson',
#  'AWS;DigitalOcean;Google Cloud;VMware',
#  'Firebase',
#  'AWS;Heroku;Linode;Microsoft Azure',
#  'Microsoft Azure;VMware',
#  'Google Cloud;Microsoft Azure',
#  'Heroku',
#  'AWS;Linode',
#  'AWS;DigitalOcean;Google Cloud',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Microsoft Azure',
#  'Managed Hosting;Microsoft Azure;VMware',
#  'Google Cloud;Linode;Microsoft Azure',
#  'Firebase;Heroku;Linode',
#  'DigitalOcean;Heroku;IBM Cloud or Watson',
#  'Managed Hosting;Microsoft Azure',
#  'AWS;Firebase',
#  'AWS;Firebase;VMware',
#  'AWS;DigitalOcean;OVH',
#  'AWS;Google Cloud;Managed Hosting',
#  'DigitalOcean;Heroku',
#  'Colocation;DigitalOcean;Google Cloud',
#  'AWS;DigitalOcean;Heroku;Microsoft Azure',
#  'AWS;Firebase;Heroku',
#  'Linode',
#  'AWS;Firebase;Google Cloud;Heroku;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Managed Hosting;Microsoft Azure;OpenStack;VMware',
#  'AWS;Google Cloud;Heroku',
#  'Colocation',
#  'DigitalOcean;OpenStack',
#  'AWS;Heroku;OpenStack',
#  'Firebase;Google Cloud;Heroku;Oracle Cloud Infrastructure',
#  'AWS;Google Cloud;OpenStack',
#  'DigitalOcean;VMware',
#  'AWS;DigitalOcean;Firebase;Heroku;Microsoft Azure',
#  'DigitalOcean;Google Cloud;Microsoft Azure',
#  'OpenStack',
#  'AWS;Google Cloud;Heroku;Microsoft Azure',
#  'Colocation;Google Cloud',
#  'AWS;Google Cloud;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud',
#  'AWS;DigitalOcean;Google Cloud;Managed Hosting;Microsoft Azure;OVH;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;IBM Cloud or Watson',
#  'Microsoft Azure;OpenStack;VMware',
#  'Google Cloud;VMware',
#  'Firebase;Heroku',
#  'AWS;Colocation;DigitalOcean;Google Cloud',
#  'DigitalOcean;Linode',
#  'AWS;DigitalOcean;Firebase',
#  'AWS;Google Cloud;Heroku;Oracle Cloud Infrastructure',
#  'DigitalOcean;Firebase;Google Cloud;Microsoft Azure',
#  'AWS;Google Cloud;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Linode;Microsoft Azure;VMware',
#  'Google Cloud;Heroku',
#  'DigitalOcean;Google Cloud',
#  'AWS;Colocation;Linode',
#  'AWS;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Heroku;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;VMware',
#  'AWS;Colocation;Google Cloud',
#  'AWS;DigitalOcean;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Heroku;Linode',
#  'AWS;Colocation;DigitalOcean;VMware',
#  'Heroku;Microsoft Azure',
#  'Firebase;Google Cloud',
#  'AWS;Firebase;Google Cloud;Heroku;VMware',
#  'AWS;Colocation;Oracle Cloud Infrastructure',
#  'AWS;Oracle Cloud Infrastructure',
#  'Microsoft Azure;OpenStack',
#  'OpenStack;VMware',
#  'Heroku;VMware',
#  'DigitalOcean;OVH',
#  'Heroku;Linode',
#  'DigitalOcean;Firebase',
#  'Linode;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Firebase;Heroku;Microsoft Azure',
#  'AWS;Colocation;Managed Hosting',
#  'AWS;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Google Cloud;OVH',
#  'Firebase;VMware',
#  'Heroku;Managed Hosting;Microsoft Azure',
#  'DigitalOcean;Firebase;Google Cloud',
#  'AWS;DigitalOcean;Google Cloud;Heroku',
#  'AWS;Colocation',
#  'AWS;Google Cloud;Managed Hosting;Microsoft Azure',
#  'Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Google Cloud;Linode',
#  'AWS;Colocation;DigitalOcean;Heroku;Microsoft Azure;VMware',
#  'AWS;Heroku;Linode',
#  'Google Cloud;Microsoft Azure;OVH',
#  'Firebase;Linode;Microsoft Azure',
#  'AWS;Firebase;Linode',
#  'AWS;Colocation;Microsoft Azure',
#  'Firebase;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode',
#  'AWS;DigitalOcean;Microsoft Azure;OpenStack;VMware',
#  'AWS;DigitalOcean;Firebase;OVH',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Heroku;Microsoft Azure;OVH',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku',
#  'OVH',
#  'Firebase;Heroku;VMware',
#  'DigitalOcean;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Google Cloud;Microsoft Azure',
#  'Firebase;Linode',
#  'Microsoft Azure;OVH',
#  'Linode;OVH',
#  'AWS;DigitalOcean;Firebase;Managed Hosting;Microsoft Azure',
#  'Firebase;Google Cloud;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Managed Hosting',
#  'AWS;DigitalOcean;Heroku;Managed Hosting',
#  'DigitalOcean;Firebase;Google Cloud;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Colocation;DigitalOcean',
#  'AWS;Firebase;Microsoft Azure',
#  'AWS;Google Cloud;Heroku;Linode',
#  'AWS;Google Cloud;Linode',
#  'AWS;DigitalOcean;Firebase;Heroku',
#  'AWS;OpenStack',
#  'AWS;Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Microsoft Azure;OpenStack',
#  'AWS;Google Cloud;Linode;Microsoft Azure',
#  'AWS;Colocation;Firebase;Google Cloud;OVH;VMware',
#  'AWS;Colocation;Google Cloud;Microsoft Azure',
#  'DigitalOcean;Managed Hosting',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Heroku;Linode',
#  'DigitalOcean;Google Cloud;Microsoft Azure;OVH',
#  'Heroku;Linode;Managed Hosting',
#  'Colocation;DigitalOcean;IBM Cloud or Watson',
#  'AWS;Linode;OpenStack',
#  'AWS;DigitalOcean;Google Cloud;OVH',
#  'AWS;Google Cloud;Heroku;OpenStack',
#  'Google Cloud;Managed Hosting',
#  'AWS;Firebase;Google Cloud;Linode;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Oracle Cloud Infrastructure;VMware',
#  'Heroku;Managed Hosting',
#  'Firebase;Google Cloud;Heroku;Linode',
#  'AWS;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;OpenStack',
#  'DigitalOcean;Google Cloud;Heroku',
#  'AWS;Firebase;Google Cloud;Linode',
#  'DigitalOcean;Firebase;Microsoft Azure',
#  'Colocation;DigitalOcean;Firebase;Heroku',
#  'Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'Google Cloud;Heroku;VMware',
#  'Google Cloud;Linode;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'Firebase;Google Cloud;Heroku;Managed Hosting',
#  'AWS;Google Cloud;OpenStack;VMware',
#  'Firebase;Google Cloud;Heroku;Microsoft Azure',
#  'DigitalOcean;Google Cloud;Linode;Oracle Cloud Infrastructure;OVH',
#  'DigitalOcean;Firebase;Heroku',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Microsoft Azure',
#  'DigitalOcean;Heroku;Linode',
#  'Managed Hosting;VMware',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Managed Hosting;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure;VMware',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;VMware',
#  'Google Cloud;OpenStack',
#  'AWS;DigitalOcean;Heroku;Linode;VMware',
#  'AWS;Microsoft Azure;OpenStack;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Linode;Oracle Cloud Infrastructure',
#  'AWS;Google Cloud;Oracle Cloud Infrastructure',
#  'Oracle Cloud Infrastructure;VMware',
#  'Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Heroku;VMware',
#  'AWS;Google Cloud;Heroku;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;Linode;OVH',
#  'AWS;Firebase;Google Cloud;VMware',
#  'AWS;Linode;Oracle Cloud Infrastructure',
#  'AWS;Google Cloud;Microsoft Azure;OVH',
#  'AWS;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Linode;VMware',
#  'AWS;Managed Hosting;OpenStack',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Linode;OpenStack',
#  'Firebase;Google Cloud;Linode',
#  'AWS;Google Cloud;Heroku;Managed Hosting',
#  'AWS;DigitalOcean;Linode;VMware',
#  'AWS;Oracle Cloud Infrastructure;VMware',
#  'AWS;Colocation;Google Cloud;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Heroku;Microsoft Azure;OpenStack;VMware',
#  'AWS;Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure;OVH;VMware',
#  'AWS;DigitalOcean;Firebase;Linode;Managed Hosting',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Microsoft Azure',
#  'AWS;DigitalOcean;Linode;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;Managed Hosting',
#  'AWS;Google Cloud;Microsoft Azure;OpenStack',
#  'AWS;Firebase;Google Cloud;Oracle Cloud Infrastructure',
#  'DigitalOcean;Heroku;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;VMware',
#  'AWS;Linode;Microsoft Azure',
#  'AWS;Colocation;DigitalOcean;Heroku;Linode',
#  'AWS;Colocation;Google Cloud;Heroku;OVH',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Managed Hosting',
#  'AWS;DigitalOcean;Managed Hosting',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Microsoft Azure;VMware',
#  'IBM Cloud or Watson;Microsoft Azure',
#  'DigitalOcean;Google Cloud;IBM Cloud or Watson;OVH',
#  'AWS;Colocation;Google Cloud;Heroku;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure',
#  'Firebase;Managed Hosting',
#  'AWS;Google Cloud;Linode;OVH;VMware',
#  'AWS;Colocation;Firebase;IBM Cloud or Watson;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Microsoft Azure;Oracle Cloud Infrastructure',
#  'Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Google Cloud;Microsoft Azure;OpenStack;VMware',
#  'AWS;Managed Hosting;VMware',
#  'AWS;Firebase;Google Cloud;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Microsoft Azure;OpenStack',
#  'AWS;Linode;Managed Hosting',
#  'Google Cloud;Linode;VMware',
#  'DigitalOcean;Linode;Microsoft Azure',
#  'IBM Cloud or Watson;VMware',
#  'DigitalOcean;Firebase;Google Cloud;Heroku',
#  'DigitalOcean;Heroku;Microsoft Azure',
#  'DigitalOcean;Managed Hosting;Microsoft Azure',
#  'AWS;Colocation;VMware',
#  'AWS;Linode;Managed Hosting;Microsoft Azure',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Heroku;Linode;Microsoft Azure',
#  'AWS;DigitalOcean;OpenStack',
#  'AWS;DigitalOcean;Linode;Managed Hosting',
#  'Colocation;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Linode',
#  'Colocation;OpenStack',
#  'Colocation;DigitalOcean;Microsoft Azure',
#  'IBM Cloud or Watson;Microsoft Azure;OpenStack',
#  'Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Google Cloud;Heroku;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Colocation;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;OVH;VMware',
#  'DigitalOcean;Google Cloud;Managed Hosting',
#  'Colocation;Google Cloud;Heroku;Microsoft Azure',
#  'DigitalOcean;Firebase;Oracle Cloud Infrastructure',
#  'Google Cloud;Linode;OpenStack',
#  'AWS;Firebase;Google Cloud;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Heroku;Managed Hosting',
#  'DigitalOcean;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Oracle Cloud Infrastructure',
#  'DigitalOcean;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Linode;Oracle Cloud Infrastructure;VMware',
#  'Google Cloud;Microsoft Azure;OpenStack',
#  'DigitalOcean;Linode;OpenStack',
#  'DigitalOcean;Google Cloud;Linode;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;Linode;Microsoft Azure',
#  'DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Linode;OVH',
#  'DigitalOcean;Heroku;Linode;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;OpenStack;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode;OpenStack;OVH;VMware',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'AWS;Firebase;Linode;Microsoft Azure',
#  'AWS;Google Cloud;Heroku;VMware',
#  'AWS;DigitalOcean;Heroku;VMware',
#  'AWS;Google Cloud;Heroku;Managed Hosting;OpenStack;VMware',
#  'DigitalOcean;Google Cloud;Linode',
#  'AWS;DigitalOcean;Firebase;Google Cloud;IBM Cloud or Watson;Linode;Microsoft Azure;OpenStack;VMware',
#  'AWS;IBM Cloud or Watson;Microsoft Azure;VMware',
#  'AWS;Colocation;Firebase;Google Cloud',
#  'DigitalOcean;Firebase;Google Cloud;Linode',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Heroku;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Microsoft Azure;VMware',
#  'DigitalOcean;IBM Cloud or Watson;Microsoft Azure;VMware',
#  'Colocation;Heroku',
#  'AWS;Colocation;Firebase;Google Cloud;Managed Hosting',
#  'AWS;Heroku;OVH',
#  'Colocation;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;OpenStack;OVH;VMware',
#  'DigitalOcean;OpenStack;OVH',
#  'Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'AWS;Google Cloud;Linode;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'Colocation;Google Cloud;Microsoft Azure;VMware',
#  'Colocation;DigitalOcean',
#  'AWS;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Managed Hosting;Microsoft Azure;OpenStack',
#  'AWS;DigitalOcean;Firebase;Heroku;Linode;VMware',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Managed Hosting;Microsoft Azure;OpenStack;VMware',
#  'AWS;Heroku;Microsoft Azure;VMware',
#  'Colocation;OpenStack;VMware',
#  'AWS;Google Cloud;Linode;Oracle Cloud Infrastructure',
#  'Colocation;Managed Hosting;VMware',
#  'AWS;DigitalOcean;Google Cloud;Managed Hosting;Microsoft Azure',
#  'AWS;Google Cloud;Heroku;Linode;Microsoft Azure',
#  'AWS;IBM Cloud or Watson',
#  'Colocation;Microsoft Azure',
#  'AWS;Microsoft Azure;OVH',
#  'AWS;OVH',
#  'AWS;DigitalOcean;Heroku;Oracle Cloud Infrastructure',
#  'AWS;Heroku;Linode;OpenStack;VMware',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Linode;Managed Hosting',
#  'AWS;Firebase;Google Cloud;Heroku;OpenStack;VMware',
#  'Google Cloud;Managed Hosting;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'Google Cloud;OVH',
#  'DigitalOcean;Google Cloud;Microsoft Azure;OpenStack',
#  'AWS;Colocation;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Google Cloud;Managed Hosting;VMware',
#  'AWS;Heroku;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Managed Hosting;Microsoft Azure;OVH;VMware',
#  'Google Cloud;Managed Hosting;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode;OVH',
#  'AWS;Firebase;Heroku;Linode',
#  'AWS;Colocation;Google Cloud;IBM Cloud or Watson;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Firebase;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Linode;Microsoft Azure',
#  'AWS;Colocation;Firebase;Google Cloud;Linode',
#  'AWS;DigitalOcean;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;IBM Cloud or Watson;Linode;Microsoft Azure;OpenStack;VMware',
#  'Managed Hosting;OpenStack;VMware',
#  'IBM Cloud or Watson;Linode',
#  'Linode;Managed Hosting;VMware',
#  'AWS;DigitalOcean;Google Cloud;Managed Hosting',
#  'AWS;Firebase;Google Cloud;IBM Cloud or Watson;Managed Hosting;Microsoft Azure;OpenStack;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode',
#  'Firebase;Google Cloud;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Microsoft Azure',
#  'Google Cloud;Heroku;Microsoft Azure',
#  'AWS;Google Cloud;Linode;Managed Hosting;VMware',
#  'AWS;DigitalOcean;Google Cloud;IBM Cloud or Watson',
#  'Colocation;DigitalOcean;VMware',
#  'AWS;Firebase;Oracle Cloud Infrastructure',
#  'AWS;IBM Cloud or Watson;VMware',
#  'AWS;Heroku;Microsoft Azure;Oracle Cloud Infrastructure',
#  'Heroku;OVH',
#  'Colocation;Firebase;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Oracle Cloud Infrastructure;OpenStack;OVH',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Managed Hosting',
#  'Google Cloud;Oracle Cloud Infrastructure',
#  'AWS;Heroku;Microsoft Azure;OpenStack',
#  'AWS;Colocation;Microsoft Azure;VMware',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;Firebase;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Heroku;Linode;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Heroku;OVH',
#  'AWS;DigitalOcean;Firebase;Heroku;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'AWS;Colocation;Firebase;Linode',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud',
#  'AWS;Linode;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Heroku;IBM Cloud or Watson;Linode',
#  'AWS;Colocation;Microsoft Azure;OpenStack;OVH',
#  'Colocation;Managed Hosting;Microsoft Azure',
#  'DigitalOcean;Google Cloud;Heroku;Microsoft Azure',
#  'DigitalOcean;Firebase;Google Cloud;Heroku;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;DigitalOcean;Google Cloud;Heroku;VMware',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Heroku;Linode;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'AWS;Google Cloud;Linode;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Linode;VMware',
#  'AWS;DigitalOcean;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;IBM Cloud or Watson;Microsoft Azure',
#  'Heroku;Linode;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'Google Cloud;Heroku;Microsoft Azure;OpenStack',
#  'AWS;DigitalOcean;Google Cloud;Linode;OVH;VMware',
#  'AWS;Colocation;Firebase;Heroku',
#  'AWS;Colocation;DigitalOcean;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;Colocation;DigitalOcean;Google Cloud;OVH',
#  'Google Cloud;IBM Cloud or Watson',
#  'Firebase;Google Cloud;Heroku;OpenStack',
#  'AWS;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Managed Hosting;Microsoft Azure;VMware',
#  'DigitalOcean;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;DigitalOcean;IBM Cloud or Watson',
#  'Firebase;Google Cloud;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Microsoft Azure;VMware',
#  'DigitalOcean;Google Cloud;VMware',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;OpenStack',
#  'AWS;DigitalOcean;Firebase;Heroku;Linode;Oracle Cloud Infrastructure;VMware',
#  'Firebase;Heroku;Managed Hosting;Microsoft Azure',
#  'Colocation;DigitalOcean;Heroku;Linode',
#  'AWS;Firebase;Managed Hosting',
#  'Google Cloud;Linode;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Microsoft Azure;VMware',
#  'DigitalOcean;Google Cloud;Heroku;Managed Hosting;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Microsoft Azure;OpenStack;VMware',
#  'AWS;DigitalOcean;Managed Hosting;OpenStack',
#  'AWS;Firebase;Heroku;VMware',
#  'AWS;Colocation;DigitalOcean;Heroku',
#  'AWS;DigitalOcean;Firebase;Linode',
#  'AWS;Google Cloud;Microsoft Azure;OVH;VMware',
#  'AWS;DigitalOcean;Heroku;Linode;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Heroku;Microsoft Azure;Oracle Cloud Infrastructure',
#  'Firebase;Linode;Managed Hosting',
#  'Colocation;Managed Hosting',
#  'AWS;DigitalOcean;Linode;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Microsoft Azure;VMware',
#  'Firebase;Google Cloud;VMware',
#  'Firebase;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Linode;VMware',
#  'DigitalOcean;Google Cloud;Managed Hosting;Microsoft Azure',
#  'Google Cloud;Linode;Microsoft Azure;VMware',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;OpenStack;OVH;VMware',
#  'AWS;DigitalOcean;Microsoft Azure;OVH;VMware',
#  'Firebase;Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Managed Hosting',
#  'DigitalOcean;Google Cloud;Heroku;Managed Hosting;Microsoft Azure',
#  'AWS;Colocation;Heroku;Managed Hosting;Microsoft Azure;VMware',
#  'DigitalOcean;Microsoft Azure;OpenStack;VMware',
#  'AWS;Google Cloud;Linode;Managed Hosting;Microsoft Azure',
#  'Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'Linode;VMware',
#  'AWS;DigitalOcean;Managed Hosting;OpenStack;OVH;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Managed Hosting;Microsoft Azure;OpenStack',
#  'AWS;Colocation;DigitalOcean;Heroku;Microsoft Azure',
#  'DigitalOcean;Linode;OVH',
#  'AWS;Colocation;DigitalOcean;Google Cloud;IBM Cloud or Watson;Microsoft Azure;OpenStack;VMware',
#  'AWS;DigitalOcean;Google Cloud;Linode;Managed Hosting',
#  'AWS;Firebase;Google Cloud;Heroku;Managed Hosting;Oracle Cloud Infrastructure',
#  'DigitalOcean;Firebase;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Colocation;DigitalOcean;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OVH',
#  'Colocation;Google Cloud;Managed Hosting',
#  'DigitalOcean;Firebase;Google Cloud;IBM Cloud or Watson;Microsoft Azure;OpenStack',
#  'Firebase;Heroku;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Heroku;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure',
#  'Google Cloud;OpenStack;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;VMware',
#  'Firebase;OpenStack',
#  'AWS;Firebase;Linode;Managed Hosting',
#  'DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure',
#  'Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Google Cloud;IBM Cloud or Watson;OVH',
#  'AWS;Colocation;Managed Hosting;VMware',
#  'Firebase;Google Cloud;IBM Cloud or Watson;Managed Hosting;OVH',
#  'Heroku;IBM Cloud or Watson',
#  'DigitalOcean;Heroku;Linode;OVH',
#  'AWS;Colocation;DigitalOcean;Linode;OVH;VMware',
#  'Colocation;Google Cloud;OpenStack;OVH;VMware',
#  'AWS;Colocation;DigitalOcean;Microsoft Azure',
#  'AWS;DigitalOcean;Heroku;IBM Cloud or Watson',
#  'AWS;DigitalOcean;IBM Cloud or Watson;OpenStack',
#  'AWS;Colocation;Firebase',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode;Managed Hosting;Microsoft Azure;OVH',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure;OpenStack',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Linode;Microsoft Azure;VMware',
#  'DigitalOcean;Firebase;Microsoft Azure;OVH',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'Firebase;Google Cloud;Heroku;VMware',
#  'Colocation;DigitalOcean;Google Cloud;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;VMware',
#  'AWS;Heroku;Linode;Managed Hosting',
#  'AWS;Heroku;Oracle Cloud Infrastructure;VMware',
#  'AWS;Firebase;Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Linode;OVH',
#  'AWS;DigitalOcean;Linode;Managed Hosting;Microsoft Azure',
#  'AWS;Google Cloud;IBM Cloud or Watson;VMware',
#  'AWS;Google Cloud;Managed Hosting;Microsoft Azure;OpenStack;VMware',
#  'Heroku;Microsoft Azure;VMware',
#  'Firebase;Google Cloud;IBM Cloud or Watson',
#  'AWS;Colocation;Firebase;Google Cloud;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Heroku;Microsoft Azure;Oracle Cloud Infrastructure',
#  'DigitalOcean;Firebase;Linode',
#  'DigitalOcean;Google Cloud;Heroku;Linode',
#  'AWS;DigitalOcean;Google Cloud;Oracle Cloud Infrastructure',
#  'AWS;Firebase;Google Cloud;OVH;VMware',
#  'AWS;DigitalOcean;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'Linode;Managed Hosting',
#  'AWS;IBM Cloud or Watson;Oracle Cloud Infrastructure',
#  'Colocation;IBM Cloud or Watson',
#  'AWS;DigitalOcean;Heroku;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'AWS;Google Cloud;IBM Cloud or Watson;Microsoft Azure;OpenStack',
#  'DigitalOcean;Google Cloud;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Linode;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'AWS;Firebase;Oracle Cloud Infrastructure;OpenStack',
#  'Linode;Microsoft Azure;VMware',
#  'Heroku;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Google Cloud;Heroku;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Firebase;Google Cloud;Managed Hosting;Microsoft Azure',
#  'DigitalOcean;Heroku;Managed Hosting',
#  'Firebase;Google Cloud;Managed Hosting',
#  'Managed Hosting;OpenStack',
#  'AWS;Colocation;Microsoft Azure;Oracle Cloud Infrastructure',
#  'DigitalOcean;Google Cloud;Linode;Managed Hosting;VMware',
#  'AWS;Firebase;Heroku;Microsoft Azure;Oracle Cloud Infrastructure',
#  'DigitalOcean;Managed Hosting;OVH',
#  'AWS;Colocation;Google Cloud;Heroku;Managed Hosting;Microsoft Azure;OpenStack;OVH;VMware',
#  'Firebase;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Heroku;Managed Hosting;Microsoft Azure',
#  'AWS;Colocation;Google Cloud;Heroku;Managed Hosting;Microsoft Azure',
#  'DigitalOcean;IBM Cloud or Watson;Microsoft Azure',
#  'Managed Hosting;Microsoft Azure;OVH',
#  'AWS;DigitalOcean;Google Cloud;Microsoft Azure;OVH',
#  'AWS;Colocation;Firebase;Google Cloud;Heroku;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Google Cloud;Heroku;Managed Hosting;Microsoft Azure',
#  'DigitalOcean;Google Cloud;Oracle Cloud Infrastructure;OpenStack',
#  'DigitalOcean;Firebase;Heroku;Linode',
#  'Colocation;DigitalOcean;OVH',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'AWS;Google Cloud;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Heroku;IBM Cloud or Watson;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;OpenStack;VMware',
#  'DigitalOcean;Firebase;Google Cloud;Oracle Cloud Infrastructure',
#  'DigitalOcean;Heroku;Linode;Microsoft Azure;VMware',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'DigitalOcean;Google Cloud;IBM Cloud or Watson;Linode;Microsoft Azure;OpenStack',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Microsoft Azure',
#  'DigitalOcean;Firebase;Google Cloud;Heroku;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Managed Hosting;OpenStack;VMware',
#  'DigitalOcean;Firebase;Google Cloud;OpenStack',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Microsoft Azure;OpenStack;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Microsoft Azure;OpenStack',
#  'AWS;DigitalOcean;Firebase;IBM Cloud or Watson',
#  'Oracle Cloud Infrastructure;OVH',
#  'Firebase;Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Google Cloud;Heroku;Linode;OpenStack;VMware',
#  'AWS;Heroku;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;Heroku;Linode',
#  'Firebase;Heroku;Linode;Microsoft Azure',
#  'Heroku;Oracle Cloud Infrastructure',
#  'DigitalOcean;Microsoft Azure;OpenStack',
#  'Google Cloud;IBM Cloud or Watson;Linode',
#  'AWS;Heroku;Oracle Cloud Infrastructure',
#  'DigitalOcean;Google Cloud;Heroku;Managed Hosting',
#  'Heroku;Microsoft Azure;OpenStack',
#  'AWS;DigitalOcean;Firebase;Heroku;IBM Cloud or Watson',
#  'DigitalOcean;Microsoft Azure;OVH',
#  'AWS;Colocation;Heroku',
#  'AWS;Colocation;Google Cloud;Microsoft Azure;OpenStack;VMware',
#  'AWS;Heroku;IBM Cloud or Watson;VMware',
#  'AWS;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'Firebase;Google Cloud;IBM Cloud or Watson;Microsoft Azure;OpenStack',
#  'AWS;Firebase;Google Cloud;Heroku;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Linode;Oracle Cloud Infrastructure;VMware',
#  'AWS;DigitalOcean;Google Cloud;OpenStack',
#  'Heroku;Microsoft Azure;OpenStack;VMware',
#  'AWS;Firebase;Managed Hosting;Microsoft Azure;OpenStack;VMware',
#  'Firebase;Heroku;Managed Hosting',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;OpenStack;OVH',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Managed Hosting',
#  'AWS;Google Cloud;Microsoft Azure;OpenStack;OVH',
#  'AWS;DigitalOcean;Google Cloud;Linode;VMware',
#  'Google Cloud;Oracle Cloud Infrastructure;VMware',
#  'Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Managed Hosting;Microsoft Azure',
#  'AWS;Google Cloud;Heroku;Linode;Microsoft Azure;VMware',
#  'AWS;Colocation;Firebase;Google Cloud;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'Firebase;Google Cloud;OVH',
#  'Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;DigitalOcean;IBM Cloud or Watson;VMware',
#  'Google Cloud;IBM Cloud or Watson;Microsoft Azure;VMware',
#  'AWS;IBM Cloud or Watson;Managed Hosting',
#  'Colocation;Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Colocation;Heroku;Linode',
#  'AWS;DigitalOcean;Firebase;Managed Hosting',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Oracle Cloud Infrastructure;OVH',
#  'AWS;Firebase;Google Cloud;Heroku;IBM Cloud or Watson',
#  'AWS;Colocation;Heroku;Microsoft Azure;VMware',
#  'AWS;Heroku;Managed Hosting;OpenStack;OVH',
#  'AWS;Colocation;Google Cloud;Managed Hosting',
#  'AWS;Colocation;Google Cloud;Microsoft Azure;OpenStack;OVH;VMware',
#  'AWS;Google Cloud;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;DigitalOcean;OpenStack;VMware',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Oracle Cloud Infrastructure;VMware',
#  'AWS;Firebase;Google Cloud;IBM Cloud or Watson;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'DigitalOcean;Linode;OpenStack;VMware',
#  'AWS;DigitalOcean;Linode;Managed Hosting;OVH',
#  'AWS;Firebase;Linode;Managed Hosting;VMware',
#  'Heroku;Managed Hosting;VMware',
#  'Google Cloud;OVH;VMware',
#  'AWS;Firebase;Google Cloud;Linode;VMware',
#  'AWS;DigitalOcean;Managed Hosting;VMware',
#  'DigitalOcean;Linode;Managed Hosting',
#  'AWS;Google Cloud;IBM Cloud or Watson;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'DigitalOcean;Heroku;Oracle Cloud Infrastructure',
#  'AWS;Colocation;DigitalOcean;Linode',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Oracle Cloud Infrastructure',
#  'DigitalOcean;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Colocation;Google Cloud;Managed Hosting;OpenStack']

# %%
#taking a quick look at 'PlatformWantToWorkWith'
df2022_US['PlatformWantToWorkWith'].dropna().unique().tolist()
# Out:
# ['Firebase;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Linode',
#  'AWS',
#  'Microsoft Azure',
#  'AWS;Google Cloud',
#  'Google Cloud',
#  'AWS;Firebase;Google Cloud;Microsoft Azure',
#  'AWS;Google Cloud;Managed Hosting;Microsoft Azure;OpenStack;VMware',
#  'AWS;Managed Hosting',
#  'DigitalOcean;Microsoft Azure',
#  'Firebase',
#  'Google Cloud;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean',
#  'AWS;Google Cloud;Microsoft Azure',
#  'AWS;Microsoft Azure',
#  'Linode',
#  'Managed Hosting',
#  'AWS;Google Cloud;Microsoft Azure;OpenStack;VMware',
#  'DigitalOcean;Heroku',
#  'AWS;DigitalOcean;Microsoft Azure',
#  'Heroku',
#  'AWS;Firebase;Google Cloud',
#  'AWS;DigitalOcean;Google Cloud',
#  'Linode;Microsoft Azure',
#  'Colocation;VMware',
#  'Google Cloud;Microsoft Azure',
#  'AWS;Google Cloud;Heroku;Managed Hosting',
#  'AWS;Linode',
#  'DigitalOcean;Google Cloud',
#  'DigitalOcean',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode',
#  'AWS;DigitalOcean;Firebase',
#  'AWS;Firebase',
#  'AWS;Firebase;Heroku;Microsoft Azure',
#  'AWS;VMware',
#  'AWS;Firebase;VMware',
#  'DigitalOcean;Linode',
#  'AWS;DigitalOcean;Linode',
#  'DigitalOcean;OVH',
#  'AWS;Google Cloud;Microsoft Azure;VMware',
#  'AWS;Firebase;Heroku',
#  'AWS;Google Cloud;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Heroku',
#  'DigitalOcean;Firebase',
#  'Colocation',
#  'DigitalOcean;OpenStack',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Heroku',
#  'AWS;OpenStack',
#  'Microsoft Azure;OVH',
#  'AWS;DigitalOcean;Google Cloud;Managed Hosting;Microsoft Azure;OVH;VMware',
#  'AWS;Firebase;Microsoft Azure',
#  'AWS;Firebase;Microsoft Azure;OpenStack',
#  'AWS;Linode;Microsoft Azure',
#  'Microsoft Azure;VMware',
#  'DigitalOcean;Google Cloud;Linode',
#  'Colocation;DigitalOcean;Google Cloud',
#  'VMware',
#  'AWS;Google Cloud;VMware',
#  'DigitalOcean;Google Cloud;Heroku;Linode',
#  'Colocation;Linode',
#  'OpenStack',
#  'AWS;Colocation',
#  'Firebase;Google Cloud;Heroku',
#  'Colocation;DigitalOcean',
#  'AWS;Heroku;Linode',
#  'Heroku;Microsoft Azure',
#  'Firebase;Google Cloud',
#  'Oracle Cloud Infrastructure',
#  'Linode;Microsoft Azure;OpenStack;VMware',
#  'AWS;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud',
#  'DigitalOcean;Firebase;Google Cloud',
#  'Heroku;Linode',
#  'AWS;Google Cloud;OpenStack',
#  'AWS;DigitalOcean;Managed Hosting;Microsoft Azure',
#  'AWS;Google Cloud;Heroku;Microsoft Azure',
#  'AWS;Firebase;Heroku;Linode',
#  'AWS;Linode;Microsoft Azure;VMware',
#  'AWS;Managed Hosting;Microsoft Azure',
#  'AWS;Colocation;Managed Hosting',
#  'AWS;Microsoft Azure;VMware',
#  'AWS;Firebase;Google Cloud;Heroku;Microsoft Azure',
#  'AWS;Google Cloud;OVH',
#  'AWS;DigitalOcean;Google Cloud;Linode',
#  'AWS;DigitalOcean;Heroku',
#  'Google Cloud;OVH',
#  'Firebase;Linode',
#  'AWS;DigitalOcean;Linode;Microsoft Azure;OpenStack',
#  'Firebase;Heroku;Microsoft Azure',
#  'Google Cloud;Heroku',
#  'AWS;DigitalOcean;Google Cloud;Microsoft Azure',
#  'AWS;OpenStack;VMware',
#  'DigitalOcean;Linode;Managed Hosting',
#  'OVH',
#  'DigitalOcean;Oracle Cloud Infrastructure',
#  'AWS;Colocation;DigitalOcean;Google Cloud;IBM Cloud or Watson;Linode;OVH',
#  'AWS;Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Microsoft Azure',
#  'Firebase;Google Cloud;Microsoft Azure',
#  'Heroku;Linode;Managed Hosting',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Microsoft Azure',
#  'DigitalOcean;Linode;Microsoft Azure',
#  'AWS;DigitalOcean;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Colocation;DigitalOcean',
#  'Firebase;Google Cloud;VMware',
#  'AWS;Google Cloud;Heroku',
#  'AWS;DigitalOcean;Heroku;Linode',
#  'AWS;Google Cloud;IBM Cloud or Watson;Microsoft Azure;OpenStack',
#  'DigitalOcean;Google Cloud;Heroku',
#  'AWS;Google Cloud;Linode',
#  'AWS;DigitalOcean;Firebase;Google Cloud;IBM Cloud or Watson;Linode;Microsoft Azure;VMware',
#  'DigitalOcean;Heroku;Linode',
#  'DigitalOcean;Google Cloud;Microsoft Azure;OVH',
#  'Colocation;Google Cloud',
#  'DigitalOcean;Google Cloud;Microsoft Azure',
#  'Colocation;DigitalOcean;IBM Cloud or Watson;OpenStack',
#  'Colocation;Google Cloud;Linode',
#  'Google Cloud;Linode',
#  'AWS;Firebase;Microsoft Azure;VMware',
#  'IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure',
#  'DigitalOcean;Firebase;Heroku',
#  'AWS;Firebase;Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'Colocation;DigitalOcean;Firebase',
#  'Google Cloud;Microsoft Azure;OpenStack',
#  'Google Cloud;VMware',
#  'AWS;Google Cloud;Linode;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;DigitalOcean;Google Cloud;Managed Hosting',
#  'AWS;DigitalOcean;Google Cloud;Linode;OVH',
#  'AWS;Google Cloud;Linode;Microsoft Azure',
#  'AWS;Google Cloud;Heroku;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'Colocation;DigitalOcean;Firebase;Linode;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku',
#  'AWS;DigitalOcean;VMware',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Heroku',
#  'Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Firebase;Google Cloud;Linode;Microsoft Azure',
#  'Oracle Cloud Infrastructure;VMware',
#  'AWS;Oracle Cloud Infrastructure;VMware',
#  'AWS;Firebase;Google Cloud;Heroku',
#  'Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Firebase;Heroku;Linode',
#  'AWS;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Oracle Cloud Infrastructure',
#  'Colocation;DigitalOcean;Firebase;Google Cloud',
#  'AWS;DigitalOcean;Google Cloud;OVH',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Microsoft Azure;OpenStack;VMware',
#  'AWS;Microsoft Azure;OpenStack',
#  'AWS;Google Cloud;Linode;Oracle Cloud Infrastructure',
#  'Linode;OpenStack',
#  'Firebase;Google Cloud;Linode',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Linode;VMware',
#  'AWS;Firebase;Google Cloud;Oracle Cloud Infrastructure;VMware',
#  'AWS;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Colocation;Google Cloud',
#  'AWS;OVH',
#  'AWS;Colocation;Microsoft Azure',
#  'DigitalOcean;Firebase;Google Cloud;Heroku',
#  'Google Cloud;Microsoft Azure;VMware',
#  'Firebase;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;VMware',
#  'IBM Cloud or Watson',
#  'Firebase;Heroku',
#  'Heroku;Linode;VMware',
#  'AWS;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Google Cloud;Heroku;Managed Hosting;Microsoft Azure',
#  'AWS;Google Cloud;IBM Cloud or Watson;VMware',
#  'Heroku;VMware',
#  'OpenStack;VMware',
#  'IBM Cloud or Watson;OpenStack',
#  'Firebase;Managed Hosting',
#  'Google Cloud;Heroku;VMware',
#  'AWS;Google Cloud;Microsoft Azure;OpenStack',
#  'AWS;Google Cloud;Managed Hosting',
#  'Managed Hosting;Microsoft Azure',
#  'DigitalOcean;Firebase;Managed Hosting',
#  'AWS;Linode;OpenStack',
#  'AWS;Managed Hosting;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'DigitalOcean;Firebase;Google Cloud;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;Heroku;Managed Hosting;Microsoft Azure',
#  'Google Cloud;Managed Hosting',
#  'Google Cloud;Linode;VMware',
#  'AWS;DigitalOcean;Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'DigitalOcean;VMware',
#  'AWS;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;VMware',
#  'AWS;DigitalOcean;Heroku;Microsoft Azure',
#  'DigitalOcean;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Linode;Managed Hosting',
#  'AWS;Heroku;Managed Hosting;Microsoft Azure',
#  'AWS;Colocation;VMware',
#  'AWS;DigitalOcean;Google Cloud;Microsoft Azure;OpenStack',
#  'AWS;DigitalOcean;OpenStack',
#  'Colocation;Managed Hosting',
#  'DigitalOcean;Google Cloud;Linode;Managed Hosting',
#  'Google Cloud;Linode;OpenStack',
#  'Managed Hosting;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Linode',
#  'DigitalOcean;Managed Hosting;Microsoft Azure',
#  'Colocation;DigitalOcean;Microsoft Azure',
#  'AWS;Google Cloud;Linode;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;Heroku;IBM Cloud or Watson;Linode;OpenStack',
#  'DigitalOcean;Managed Hosting',
#  'Linode;OVH',
#  'AWS;DigitalOcean;Google Cloud;Heroku',
#  'Firebase;Google Cloud;Managed Hosting',
#  'AWS;Firebase;Google Cloud;Linode',
#  'DigitalOcean;Google Cloud;Managed Hosting',
#  'AWS;DigitalOcean;Google Cloud;Microsoft Azure;VMware',
#  'AWS;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure;VMware',
#  'AWS;Linode;Microsoft Azure;OpenStack',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Linode;VMware',
#  'AWS;Colocation;OVH',
#  'AWS;DigitalOcean;Heroku;Managed Hosting',
#  'Heroku;Managed Hosting',
#  'AWS;Google Cloud;Managed Hosting;OpenStack',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'Google Cloud;Linode;Managed Hosting',
#  'AWS;Linode;Managed Hosting',
#  'Firebase;Linode;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;IBM Cloud or Watson;Linode;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'AWS;Firebase;Google Cloud;Heroku;Managed Hosting',
#  'AWS;Colocation;Firebase;Google Cloud',
#  'DigitalOcean;Google Cloud;OpenStack;VMware',
#  'AWS;Colocation;Firebase;Managed Hosting',
#  'DigitalOcean;IBM Cloud or Watson',
#  'Colocation;DigitalOcean;OpenStack;OVH',
#  'Managed Hosting;VMware',
#  'Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'DigitalOcean;Google Cloud;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;Linode;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Microsoft Azure;OpenStack;VMware',
#  'DigitalOcean;Google Cloud;Linode;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Heroku;Linode;Microsoft Azure',
#  'Colocation;OpenStack;VMware',
#  'AWS;Linode;VMware',
#  'Colocation;Managed Hosting;VMware',
#  'AWS;DigitalOcean;Google Cloud;Managed Hosting;Microsoft Azure',
#  'AWS;Firebase;Linode',
#  'Google Cloud;Heroku;IBM Cloud or Watson;Linode;Microsoft Azure',
#  'AWS;IBM Cloud or Watson',
#  'Colocation;Microsoft Azure',
#  'AWS;Microsoft Azure;OVH',
#  'Firebase;OpenStack',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Linode;Managed Hosting',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Managed Hosting;Microsoft Azure',
#  'Firebase;Google Cloud;Heroku;Linode',
#  'Google Cloud;OpenStack;VMware',
#  'AWS;Firebase;Google Cloud;Oracle Cloud Infrastructure',
#  'AWS;Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'Linode;Microsoft Azure;OpenStack',
#  'Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'DigitalOcean;Google Cloud;Microsoft Azure;OpenStack',
#  'AWS;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'DigitalOcean;Google Cloud;Heroku;Managed Hosting;OpenStack',
#  'AWS;Google Cloud;Oracle Cloud Infrastructure',
#  'AWS;Colocation;Managed Hosting;VMware',
#  'Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Colocation;Google Cloud;Linode',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Colocation;DigitalOcean;VMware',
#  'Managed Hosting;OpenStack',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode',
#  'AWS;Google Cloud;Linode;Managed Hosting',
#  'AWS;Google Cloud;Heroku;Microsoft Azure;OpenStack',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Microsoft Azure',
#  'Google Cloud;Managed Hosting;Microsoft Azure',
#  'AWS;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Google Cloud;IBM Cloud or Watson',
#  'Google Cloud;Microsoft Azure;OpenStack;OVH;VMware',
#  'Colocation;DigitalOcean;Heroku',
#  'AWS;DigitalOcean;Firebase;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;VMware',
#  'AWS;Managed Hosting;OVH',
#  'AWS;Google Cloud;Heroku;Microsoft Azure;VMware',
#  'Firebase;Google Cloud;Heroku;Microsoft Azure',
#  'Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Google Cloud;OpenStack;VMware',
#  'Colocation;Firebase;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Oracle Cloud Infrastructure;OpenStack;OVH',
#  'Managed Hosting;OpenStack;VMware',
#  'DigitalOcean;Firebase;Linode',
#  'OpenStack;OVH',
#  'AWS;Google Cloud;IBM Cloud or Watson;Microsoft Azure;OpenStack;VMware',
#  'AWS;Google Cloud;Microsoft Azure;OVH',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH',
#  'Google Cloud;Heroku;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Microsoft Azure',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson',
#  'AWS;DigitalOcean;Google Cloud;Linode;Managed Hosting;Microsoft Azure;OpenStack',
#  'Colocation;Managed Hosting;Oracle Cloud Infrastructure',
#  'AWS;Heroku;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud',
#  'Google Cloud;Heroku;Linode',
#  'AWS;DigitalOcean;Heroku;Linode;Microsoft Azure',
#  'Colocation;Managed Hosting;Microsoft Azure',
#  'AWS;Colocation;DigitalOcean;Firebase;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH',
#  'AWS;Colocation;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;DigitalOcean;Google Cloud;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Firebase;Google Cloud;Heroku;Linode',
#  'DigitalOcean;Firebase;Linode;VMware',
#  'Microsoft Azure;OpenStack;VMware',
#  'AWS;DigitalOcean;Google Cloud;Linode;OpenStack',
#  'AWS;Heroku;Managed Hosting',
#  'AWS;DigitalOcean;Firebase;VMware',
#  'DigitalOcean;Firebase;Google Cloud;Linode',
#  'AWS;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Microsoft Azure;OpenStack',
#  'Google Cloud;Linode;OVH',
#  'AWS;DigitalOcean;Firebase;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Firebase;Heroku;OpenStack',
#  'Heroku;OpenStack',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;OpenStack',
#  'DigitalOcean;Linode;VMware',
#  'Linode;Microsoft Azure;VMware',
#  'Firebase;Google Cloud;Heroku;OpenStack',
#  'AWS;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Microsoft Azure;VMware',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Google Cloud;IBM Cloud or Watson',
#  'IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;IBM Cloud or Watson;Oracle Cloud Infrastructure',
#  'Firebase;Google Cloud;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Heroku;IBM Cloud or Watson;OpenStack',
#  'AWS;Firebase;Heroku;Managed Hosting',
#  'AWS;DigitalOcean;Firebase;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;OpenStack',
#  'AWS;Firebase;Google Cloud;Heroku;Linode;VMware',
#  'Firebase;Google Cloud;IBM Cloud or Watson',
#  'AWS;Colocation;DigitalOcean;Google Cloud',
#  'Google Cloud;Linode;Managed Hosting;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Linode;Microsoft Azure;VMware',
#  'Firebase;Linode;Managed Hosting;Microsoft Azure',
#  'DigitalOcean;Firebase;Google Cloud;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Microsoft Azure;VMware',
#  'AWS;Firebase;Google Cloud;VMware',
#  'AWS;Firebase;Google Cloud;Linode;VMware',
#  'AWS;Colocation;OpenStack',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;OpenStack;OVH;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode;Microsoft Azure',
#  'Google Cloud;OpenStack',
#  'AWS;Firebase;Google Cloud;Managed Hosting',
#  'AWS;Google Cloud;Managed Hosting;VMware',
#  'Firebase;Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'DigitalOcean;Managed Hosting;OpenStack;VMware',
#  'DigitalOcean;Firebase;Microsoft Azure',
#  'Colocation;DigitalOcean;IBM Cloud or Watson',
#  'AWS;DigitalOcean;Managed Hosting',
#  'Colocation;Firebase;Google Cloud;Heroku;Managed Hosting;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure',
#  'AWS;Colocation;DigitalOcean;Oracle Cloud Infrastructure',
#  'DigitalOcean;Firebase;Heroku;Microsoft Azure',
#  'Firebase;Microsoft Azure;VMware',
#  'AWS;Colocation;Heroku;Linode;Managed Hosting;Oracle Cloud Infrastructure;OVH;VMware',
#  'Heroku;IBM Cloud or Watson',
#  'DigitalOcean;Firebase;Google Cloud;Heroku;Linode;Microsoft Azure',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Microsoft Azure;OpenStack;VMware',
#  'DigitalOcean;Microsoft Azure;VMware',
#  'Linode;OpenStack;OVH',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'AWS;Firebase;Linode;Managed Hosting',
#  'Colocation;Linode;OVH;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;IBM Cloud or Watson;Linode;OVH',
#  'AWS;DigitalOcean;Google Cloud;IBM Cloud or Watson;OVH',
#  'AWS;DigitalOcean;Firebase;IBM Cloud or Watson;Managed Hosting;OVH',
#  'AWS;DigitalOcean;Firebase;Google Cloud;IBM Cloud or Watson',
#  'AWS;Colocation;Linode;OVH;VMware',
#  'AWS;Heroku;OpenStack',
#  'IBM Cloud or Watson;VMware',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode;Managed Hosting;Microsoft Azure;OVH',
#  'AWS;Firebase;Managed Hosting;Microsoft Azure',
#  'Google Cloud;Managed Hosting;VMware',
#  'AWS;Google Cloud;IBM Cloud or Watson;Managed Hosting;Oracle Cloud Infrastructure;VMware',
#  'Linode;Managed Hosting',
#  'AWS;IBM Cloud or Watson;Linode;OpenStack',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'Linode;VMware',
#  'DigitalOcean;Google Cloud;Linode;Microsoft Azure;OpenStack',
#  'Managed Hosting;Oracle Cloud Infrastructure',
#  'AWS;Colocation;DigitalOcean;OpenStack',
#  'DigitalOcean;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Google Cloud;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Firebase;IBM Cloud or Watson',
#  'Firebase;IBM Cloud or Watson',
#  'AWS;Colocation;Google Cloud;IBM Cloud or Watson;OpenStack;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;OVH',
#  'AWS;Google Cloud;IBM Cloud or Watson;Linode;Microsoft Azure',
#  'Colocation;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;OVH',
#  'Colocation;DigitalOcean;Firebase;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'AWS;DigitalOcean;Microsoft Azure;VMware',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'Firebase;Oracle Cloud Infrastructure',
#  'AWS;Google Cloud;Heroku;OpenStack;VMware',
#  'AWS;DigitalOcean;Firebase;Linode;VMware',
#  'AWS;DigitalOcean;Google Cloud;Microsoft Azure;OpenStack;OVH',
#  'AWS;Colocation;Google Cloud;Microsoft Azure',
#  'Heroku;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;Linode;Microsoft Azure;VMware',
#  'AWS;Firebase;Managed Hosting',
#  'Google Cloud;Heroku;Linode;Microsoft Azure',
#  'AWS;Google Cloud;Heroku;IBM Cloud or Watson;Microsoft Azure;VMware',
#  'Heroku;Linode;Managed Hosting;Microsoft Azure;VMware',
#  'AWS;Managed Hosting;OpenStack',
#  'DigitalOcean;Heroku;Managed Hosting',
#  'Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;DigitalOcean;Google Cloud;VMware',
#  'DigitalOcean;Heroku;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Google Cloud;IBM Cloud or Watson;VMware',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Firebase;Google Cloud;IBM Cloud or Watson;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'AWS;Firebase;OpenStack',
#  'AWS;Firebase;Managed Hosting;Microsoft Azure;OVH;VMware',
#  'AWS;Heroku;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;Colocation;Firebase;Google Cloud;Heroku;Microsoft Azure;VMware',
#  'Colocation;DigitalOcean;Linode;Managed Hosting',
#  'AWS;Google Cloud;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'Firebase;Google Cloud;IBM Cloud or Watson;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'AWS;DigitalOcean;Linode;Microsoft Azure;OpenStack;VMware',
#  'AWS;Heroku;IBM Cloud or Watson;OpenStack;VMware',
#  'AWS;Colocation;DigitalOcean;OVH',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'DigitalOcean;Firebase;Google Cloud;Heroku;Linode',
#  'AWS;Google Cloud;Heroku;IBM Cloud or Watson;VMware',
#  'AWS;Google Cloud;Heroku;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'Google Cloud;Managed Hosting;OpenStack',
#  'DigitalOcean;Google Cloud;Oracle Cloud Infrastructure',
#  'AWS;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'DigitalOcean;Google Cloud;IBM Cloud or Watson;Linode;Microsoft Azure;OpenStack',
#  'AWS;Heroku;IBM Cloud or Watson;Microsoft Azure',
#  'Firebase;Google Cloud;IBM Cloud or Watson;Linode',
#  'AWS;Colocation;DigitalOcean;Heroku;Linode',
#  'AWS;Colocation;DigitalOcean;Linode;OpenStack;VMware',
#  'Firebase;Heroku;Linode',
#  'AWS;Google Cloud;Heroku;IBM Cloud or Watson;Microsoft Azure;OpenStack',
#  'DigitalOcean;Firebase;Google Cloud;Microsoft Azure;OpenStack',
#  'DigitalOcean;Firebase;Google Cloud;OpenStack',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Linode;Microsoft Azure;OpenStack',
#  'Google Cloud;Oracle Cloud Infrastructure;OVH',
#  'AWS;Colocation;DigitalOcean;Linode;Managed Hosting;OVH;VMware',
#  'AWS;Colocation;DigitalOcean;Firebase;Heroku;Linode;Managed Hosting;OpenStack;OVH',
#  'AWS;IBM Cloud or Watson;VMware',
#  'Google Cloud;IBM Cloud or Watson',
#  'AWS;Google Cloud;Heroku;Linode;OpenStack;VMware',
#  'DigitalOcean;Microsoft Azure;OpenStack',
#  'AWS;Colocation;Google Cloud;OpenStack',
#  'Oracle Cloud Infrastructure;OpenStack;VMware',
#  'AWS;Firebase;Google Cloud;Heroku;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'Heroku;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Firebase;Managed Hosting',
#  'AWS;IBM Cloud or Watson;Linode;Microsoft Azure;VMware',
#  'AWS;Google Cloud;Linode;Microsoft Azure;VMware',
#  'Google Cloud;Linode;Microsoft Azure',
#  'DigitalOcean;Microsoft Azure;OVH',
#  'AWS;Firebase;Microsoft Azure;Oracle Cloud Infrastructure',
#  'Colocation;DigitalOcean;OpenStack',
#  'IBM Cloud or Watson;Microsoft Azure;VMware',
#  'Google Cloud;Heroku;Microsoft Azure;VMware',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Heroku;Linode;VMware',
#  'AWS;Google Cloud;Linode;VMware',
#  'AWS;Firebase;Google Cloud;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'AWS;DigitalOcean;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;VMware',
#  'Microsoft Azure;OpenStack',
#  'Heroku;OVH',
#  'DigitalOcean;Google Cloud;Linode;Microsoft Azure',
#  'AWS;IBM Cloud or Watson;Managed Hosting',
#  'DigitalOcean;Firebase;Google Cloud;IBM Cloud or Watson',
#  'AWS;DigitalOcean;Google Cloud;Linode;VMware',
#  'Firebase;Heroku;OpenStack',
#  'AWS;Colocation;Firebase;Google Cloud;Microsoft Azure;VMware',
#  'DigitalOcean;Heroku;OVH',
#  'AWS;Colocation;DigitalOcean;Google Cloud;Heroku;Linode;Microsoft Azure;OpenStack',
#  'Firebase;Google Cloud;Oracle Cloud Infrastructure',
#  'AWS;DigitalOcean;Linode;Microsoft Azure',
#  'AWS;Colocation;Google Cloud;Microsoft Azure;VMware',
#  'Colocation;Google Cloud;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Colocation;Linode',
#  'Colocation;DigitalOcean;Heroku;OpenStack',
#  'AWS;DigitalOcean;Firebase;Google Cloud;Linode;Microsoft Azure;Oracle Cloud Infrastructure',
#  'Colocation;DigitalOcean;Firebase;Heroku;IBM Cloud or Watson;Linode;OVH;VMware',
#  'AWS;DigitalOcean;Google Cloud;IBM Cloud or Watson;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack',
#  'AWS;IBM Cloud or Watson;Microsoft Azure;VMware',
#  'Linode;OpenStack;VMware',
#  'AWS;Colocation;DigitalOcean;Firebase;Heroku;IBM Cloud or Watson;Linode;Managed Hosting;Oracle Cloud Infrastructure;OpenStack;OVH;VMware',
#  'DigitalOcean;Firebase;Heroku;IBM Cloud or Watson',
#  'AWS;DigitalOcean;Google Cloud;Heroku;Linode;Managed Hosting',
#  'AWS;DigitalOcean;Linode;OVH;VMware',
#  'AWS;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Microsoft Azure',
#  'AWS;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Managed Hosting;Microsoft Azure;OpenStack',
#  'Colocation;DigitalOcean;Managed Hosting',
#  'AWS;DigitalOcean;Heroku;OpenStack',
#  'AWS;Google Cloud;Heroku;OVH',
#  'AWS;Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;IBM Cloud or Watson;Managed Hosting;Microsoft Azure;Oracle Cloud Infrastructure;OpenStack;VMware',
#  'AWS;DigitalOcean;Linode;OVH',
#  'Colocation;DigitalOcean;Firebase;Google Cloud;Heroku;Linode',
#  'AWS;Google Cloud;Heroku;VMware',
#  'AWS;Colocation;DigitalOcean;Linode',
#  'Google Cloud;Linode;Microsoft Azure;VMware',
#  'DigitalOcean;Firebase;OpenStack',
#  'IBM Cloud or Watson;Managed Hosting;VMware',
#  'DigitalOcean;Microsoft Azure;Oracle Cloud Infrastructure',
#  'AWS;Colocation;Heroku',
#  'Heroku;Linode;Microsoft Azure',
#  'Colocation;Google Cloud;Managed Hosting;OpenStack',
#  'Firebase;Linode;Managed Hosting;Microsoft Azure;VMware']

# %% [markdown]
# In both columns the answers were select all that apply, and were put into one cell for each participant. In order to compare frequencies, I need to split the values for each cell and put them in a new row to count them.

# %%
#using the function explode() to separate each answers from cells with multiple platforms selected and creating a new row.
df2022_US_explode_currentplatforms = df2022_US.assign(platforms=df2022_US.PlatformHaveWorkedWith.str.split(';')).explode('platforms').reset_index(drop=True)

# %%
# check if percent makes sense
df2022_US_explode_currentplatforms['platforms'].value_counts()/df2022_US_explode_currentplatforms.shape[0]
# Out:
# AWS                            0.276285
# Microsoft Azure                0.132936
# Google Cloud                   0.114097
# DigitalOcean                   0.071696
# Heroku                         0.068564
# Firebase                       0.055372
# VMware                         0.038473
# Linode                         0.023119
# Managed Hosting                0.018972
# Colocation                     0.009530
# Oracle Cloud Infrastructure    0.009221
# OpenStack                      0.008868
# IBM Cloud or Watson            0.007412
# OVH                            0.005427
# Name: platforms, dtype: float64

# %%
# making a histogram of counts for each platform using the new df for currently used platforms, and ordering from highest value count to lowest
plt.figure(figsize=(10,5))
chart = sns.countplot(
    data=df2022_US_explode_currentplatforms,
    x='platforms',
    order=df2022_US_explode_currentplatforms['platforms'].value_counts().index,
    color='grey'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'AWS'),
#  Text(1, 0, 'Microsoft Azure'),
#  Text(2, 0, 'Google Cloud'),
#  Text(3, 0, 'DigitalOcean'),
#  Text(4, 0, 'Heroku'),
#  Text(5, 0, 'Firebase'),
#  Text(6, 0, 'VMware'),
#  Text(7, 0, 'Linode'),
#  Text(8, 0, 'Managed Hosting'),
#  Text(9, 0, 'Colocation'),
#  Text(10, 0, 'Oracle Cloud Infrastructure'),
#  Text(11, 0, 'OpenStack'),
#  Text(12, 0, 'IBM Cloud or Watson'),
#  Text(13, 0, 'OVH')]

# %%
#plot in percent
plt.figure(figsize=(10,5))
chart = sns.countplot(
    data=df2022_US_explode_currentplatforms,
    x='platforms',
    order=df2022_US_explode_currentplatforms['platforms'].value_counts().index,
    color='grey'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)

# %%
# extracting the value counts for each platform
df2022_US_explode_currentplatforms['platforms'].dropna().value_counts()
# Out:
# AWS                            6262
# Microsoft Azure                3013
# Google Cloud                   2586
# DigitalOcean                   1625
# Heroku                         1554
# Firebase                       1255
# VMware                          872
# Linode                          524
# Managed Hosting                 430
# Colocation                      216
# Oracle Cloud Infrastructure     209
# OpenStack                       201
# IBM Cloud or Watson             168
# OVH                             123
# Name: platforms, dtype: int64

# %% [markdown]
# The big 5 cloud platforms that are being used are AWS, Microsoft Azure, Google Cloud, Digital Ocean, and Heroku

# %% [markdown]
# Now let's do the same for the platform that participants want to work with.

# %%
#using explode() to retrieve individual platforms in a row
df2022_US_explode_wantplatforms = df2022_US.assign(platforms=df2022_US.PlatformWantToWorkWith.str.split(';')).explode('platforms').reset_index(drop=True)

# %%
# building the histogram of platforms that people want to work with
plt.figure(figsize=(10,5))
chart = sns.countplot(
    data=df2022_US_explode_wantplatforms,
    x='platforms',
    order=df2022_US_explode_wantplatforms['platforms'].value_counts().index,
    color='purple'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
chart.set_title("Platforms that participants want to work with")
# Out:
# Text(0.5, 1.0, 'Platforms that participants want to learn about')

# %%
#retrieving value counts
df2022_US_explode_wantplatforms['platforms'].dropna().value_counts()
# Out:
# AWS                            4806
# Microsoft Azure                2380
# Google Cloud                   2234
# DigitalOcean                   1310
# Firebase                        975
# Heroku                          817
# Linode                          574
# VMware                          451
# Managed Hosting                 263
# OpenStack                       231
# Oracle Cloud Infrastructure     176
# Colocation                      150
# IBM Cloud or Watson             140
# OVH                              91
# Name: platforms, dtype: int64

# %% [markdown]
# AWS is the most popular platform in terms of current usage and what participant want to learn.

# %%
df2022_US_explode_wantplatforms['platforms'].dropna().value_counts()/df2022_US_explode_currentplatforms['platforms'].dropna().value_counts()
# Out:
# AWS                            0.767486
# Colocation                     0.694444
# DigitalOcean                   0.806154
# Firebase                       0.776892
# Google Cloud                   0.863882
# Heroku                         0.525740
# IBM Cloud or Watson            0.833333
# Linode                         1.095420
# Managed Hosting                0.611628
# Microsoft Azure                0.789910
# OVH                            0.739837
# OpenStack                      1.149254
# Oracle Cloud Infrastructure    0.842105
# VMware                         0.517202
# Name: platforms, dtype: float64

# %%
# putting plots next to each other
chart=sns.countplot(
    data=df2022_US_explode_currentplatforms,
    x='platforms',
    order=df2022_US_explode_currentplatforms['platforms'].value_counts().index,
    color='grey'
)
#chart1.set_xticklabels(chart.get_xticklabels(), rotation=90)

chart=sns.countplot(
    data=df2022_US_explode_wantplatforms,
    x='platforms',
    order=df2022_US_explode_wantplatforms['platforms'].value_counts().index,
    color='purple'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'AWS'),
#  Text(1, 0, 'Microsoft Azure'),
#  Text(2, 0, 'Google Cloud'),
#  Text(3, 0, 'DigitalOcean'),
#  Text(4, 0, 'Firebase'),
#  Text(5, 0, 'Heroku'),
#  Text(6, 0, 'Linode'),
#  Text(7, 0, 'VMware'),
#  Text(8, 0, 'Managed Hosting'),
#  Text(9, 0, 'OpenStack'),
#  Text(10, 0, 'Oracle Cloud Infrastructure'),
#  Text(11, 0, 'Colocation'),
#  Text(12, 0, 'IBM Cloud or Watson'),
#  Text(13, 0, 'OVH')]

# %%
ratio=(df2022_US_explode_wantplatforms['platforms'].dropna().value_counts()/df2022_US_explode_currentplatforms['platforms'].dropna().value_counts())-1

ratio1=ratio.to_frame()
ratio1
# Out:
#                              platforms
# AWS                          -0.232514
# Colocation                   -0.305556
# DigitalOcean                 -0.193846
# Firebase                     -0.223108
# Google Cloud                 -0.136118
# Heroku                       -0.474260
# IBM Cloud or Watson          -0.166667
# Linode                        0.095420
# Managed Hosting              -0.388372
# Microsoft Azure              -0.210090
# OVH                          -0.260163
# OpenStack                     0.149254
# Oracle Cloud Infrastructure  -0.157895
# VMware                       -0.482798

# %%
ratio1['platforms'].sort_values().plot(kind='barh',title="What cloud platform participants want to use in 2022?"
                         ,color =(ratio1['platforms'] > 0).map({True: 'violet',False: 'lightgrey'}))
#NB: not sure why I could not have positive values in purple and negative values in or
# Out:
# <AxesSubplot:title={'center':'What cloud platform participants want to use in 2022?'}>

# %% [markdown]
# #### Conclusion the two main cloud platforms that could be trending are Openstack and Linode.

# %% [markdown]
# Let's focus on people who were coding as a profession and see if the trend is the same

# %%
df2022_US['MainBranch'].value_counts() # I want to subset by people who code as a profession
# Out:
# I am a developer by profession                                                   10288
# I am not primarily a developer, but I write code sometimes as part of my work     1256
# I code primarily as a hobby                                                       1060
# I am learning to code                                                              673
# I used to be a developer by profession, but no longer am                           266
# Name: MainBranch, dtype: int64

# %%
df2022_USpro=df2022_US[df2022_US['MainBranch']=='I am a developer by profession']

# %%
df2022_USpro_explode_currentplatforms = df2022_USpro.assign(platforms=df2022_USpro.PlatformHaveWorkedWith.str.split(';')).explode('platforms').reset_index(drop=True)
df2022_USpro_explode_currentplatforms['platforms'].dropna().value_counts()
# Out:
# AWS                            5365
# Microsoft Azure                2546
# Google Cloud                   1983
# DigitalOcean                   1309
# Heroku                         1131
# Firebase                        971
# VMware                          607
# Linode                          396
# Managed Hosting                 317
# Colocation                      168
# OpenStack                       139
# Oracle Cloud Infrastructure     126
# IBM Cloud or Watson             109
# OVH                              80
# Name: platforms, dtype: int64

# %%
df2022_USpro_explode_wantplatforms = df2022_USpro.assign(platforms=df2022_USpro.PlatformWantToWorkWith.str.split(';')).explode('platforms').reset_index(drop=True)
df2022_USpro_explode_wantplatforms['platforms'].dropna().value_counts()
# Out:
# AWS                            4001
# Microsoft Azure                1958
# Google Cloud                   1724
# DigitalOcean                   1027
# Firebase                        735
# Heroku                          575
# Linode                          426
# VMware                          286
# Managed Hosting                 184
# OpenStack                       165
# Colocation                      105
# Oracle Cloud Infrastructure      95
# IBM Cloud or Watson              77
# OVH                              55
# Name: platforms, dtype: int64

# %%
ratio_pro=(df2022_USpro_explode_wantplatforms['platforms'].dropna().value_counts()/df2022_USpro_explode_currentplatforms['platforms'].dropna().value_counts()-1)

# %%
ratio_pro.sort_values().plot(kind='barh',
                             title="What cloud platform has demand in the US in 2022 with people who code as a profession?",
                            color =(ratio1['platforms'] > 0).map({True: 'violet',False: 'lightgrey'}))
# Out:
# <AxesSubplot:title={'center':'What cloud platform has demand in the US in 2022 with people who code as a profession?'}>

# %% [markdown]
# The trend is the same if we only consider participant who code as a profession.

# %% [markdown]
# ## Question 2: what programming language should I learn?
# In order to answer that question, I decided to examine
# 'LanguageHaveWorkedWith',
# 'LanguageWantToWorkWith'
# 'LearnCodeCoursesCert' -> to see what vertification stands out by coding language
# 'DevType' -> by dev type is an important
#
# Since I have filtered by country (USA) and by people who code as a profession, I will do the same here.

# %% [markdown]
# Let's take a look at the features I want to examine.

# %%
df2022_USpro.DevType.unique() # this one is tricky, let's put it aside for now. I could first explode Dev type, then subset by dev type and explode each language (cry emoji)
# Out:
# array(['Developer, front-end;Developer, full-stack;Developer, back-end;Developer, desktop or enterprise applications;Developer, QA or test',
#        'Developer, full-stack',
#        'Developer, full-stack;Academic researcher;DevOps specialist', ...,
#        'Data scientist or machine learning specialist;Developer, full-stack;Engineering manager;Product manager',
#        'Developer, front-end;Engineer, data;Engineer, site reliability;Developer, full-stack;Developer, back-end;Developer, QA or test;Developer, mobile;Engineering manager;Database administrator;Cloud infrastructure engineer;Data or business analyst;Designer;System administrator;Security professional',
#        'Data scientist or machine learning specialist;Developer, back-end;Project manager;Data or business analyst'],
#       dtype=object)

# %%
df2022_USpro.LanguageHaveWorkedWith.unique().tolist()
# Out:
# ['C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript',
#  'C;HTML/CSS;Rust;SQL;Swift;TypeScript',
#  'HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala',
#  'Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;SQL',
#  'C;C++',
#  'C#;HTML/CSS;JavaScript;SQL',
#  'C#;C++;HTML/CSS;JavaScript;SQL;TypeScript;VBA',
#  'Java;JavaScript;PHP;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;SQL;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;C;Go;HTML/CSS;Java;JavaScript;Python;Swift;TypeScript',
#  'C#;JavaScript;Python;SQL',
#  'Bash/Shell;Java;Python;SQL',
#  'Bash/Shell;HTML/CSS;JavaScript;PHP;TypeScript',
#  'Bash/Shell;C;C++;Python',
#  'C#;HTML/CSS;Java;JavaScript;Python;SQL;VBA',
#  'JavaScript;SQL',
#  'Python;SQL;VBA',
#  'Bash/Shell;HTML/CSS;JavaScript;PHP;R;SQL',
#  'Java;Python;SQL',
#  'C#',
#  'Bash/Shell;Go;JavaScript;Python;TypeScript',
#  'C#;HTML/CSS;JavaScript;PowerShell;TypeScript',
#  'C#;JavaScript;Perl;Python;Ruby;SQL',
#  'Go;HTML/CSS;Java;JavaScript;Python;SQL',
#  'C++;Go;Java;JavaScript;SQL;TypeScript',
#  'C#;JavaScript;Kotlin;SQL',
#  'HTML/CSS;JavaScript;Python;R;SQL;TypeScript',
#  'Java;Python;TypeScript',
#  'Bash/Shell;C;Python',
#  'C;C#;C++;Java;JavaScript;Perl;PHP;PowerShell;SQL;TypeScript;VBA',
#  'Clojure;Java;Rust',
#  'Assembly;C;C#;C++;Dart;HTML/CSS;Java;JavaScript;TypeScript',
#  'Bash/Shell;C;C#;C++;Go;Java;JavaScript;Python;SQL;Swift;TypeScript',
#  'Groovy;Java;Python;Rust',
#  'C#;HTML/CSS;JavaScript;Python',
#  'Bash/Shell;C++;Java;Python',
#  'C#;JavaScript;PowerShell',
#  'Bash/Shell;C;C++;Dart;HTML/CSS;Java;JavaScript;Objective-C;Swift',
#  'C#;HTML/CSS;JavaScript;TypeScript',
#  'C;JavaScript;Python;SQL;TypeScript',
#  'C#;C++;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript',
#  'JavaScript',
#  'C#;SQL',
#  'Rust',
#  'C#;HTML/CSS;JavaScript;PowerShell;Python;SQL',
#  'Go',
#  'Bash/Shell;Go;HTML/CSS;Python;SQL',
#  'Go;HTML/CSS;JavaScript;Kotlin;PHP;Python;SQL',
#  'C#;C++;HTML/CSS;JavaScript;SQL;Swift;TypeScript',
#  'C++;HTML/CSS;JavaScript;PHP;Python',
#  'Bash/Shell;Groovy;Java;JavaScript;PHP;Python;Rust;SQL',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C;C#;C++;Java;PowerShell',
#  'C#;JavaScript;Python',
#  'C#;Go;Rust;TypeScript',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
#  'C;JavaScript;Python;Scala',
#  'C#;Dart;HTML/CSS;JavaScript;PowerShell;Python;TypeScript',
#  'C#;C++;HTML/CSS;Java;JavaScript;Perl;PowerShell;Python;Ruby;SAS;SQL;TypeScript;VBA',
#  'HTML/CSS;JavaScript;Python;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;Python;SQL',
#  'Bash/Shell;C#;Go;HTML/CSS;JavaScript;PowerShell;Python',
#  'Go;Python;SQL',
#  'Python;Rust',
#  'HTML/CSS;JavaScript;PHP;TypeScript',
#  'C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript',
#  'Bash/Shell;Go;Python',
#  'HTML/CSS;JavaScript;Python;Scala;SQL;TypeScript',
#  'Bash/Shell;C#;PowerShell;SQL',
#  'Bash/Shell;C#;PowerShell;Python',
#  'C++;JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;PHP;SQL',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Python;Ruby;SQL;TypeScript',
#  'Bash/Shell;C++;HTML/CSS;Java;JavaScript;Python;SQL',
#  'HTML/CSS;Java;JavaScript;Kotlin;Python;TypeScript',
#  'Kotlin',
#  'Bash/Shell;Java;JavaScript;PHP;SQL',
#  'Assembly;Bash/Shell;C;MATLAB;Python',
#  'Bash/Shell;C++;Dart;Go;HTML/CSS;Java;JavaScript;Python;Rust;SQL',
#  'C#;Java;JavaScript;Lua;PowerShell;Python;SQL',
#  'C#;Java',
#  'C#;Elixir;PowerShell;SQL;TypeScript',
#  'Go;MATLAB;Python;Rust',
#  'Bash/Shell;C;C#;C++;F#;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;PHP;Python;SQL',
#  'Bash/Shell;C#;HTML/CSS;Java;JavaScript;Lua;PowerShell;Python;SQL',
#  'Bash/Shell;HTML/CSS;JavaScript;Rust;SQL;TypeScript',
#  'Java;JavaScript;SQL',
#  'C#;Elixir;Erlang;F#;Go;HTML/CSS;JavaScript;PowerShell;Rust;SQL;Swift;TypeScript',
#  'APL;Bash/Shell;C;C++;Go;Haskell;LISP;Perl;Python;Rust',
#  'Bash/Shell;C#;Java;Kotlin;PowerShell;Python;SQL;VBA',
#  'Bash/Shell;C;C#;C++;HTML/CSS;Java;JavaScript;Python;SQL',
#  'Bash/Shell;Elixir;Go;Haskell;JavaScript',
#  'HTML/CSS;JavaScript;Kotlin;Python;Rust;TypeScript',
#  'Assembly;C#;C++;HTML/CSS;JavaScript;PowerShell;SQL',
#  'HTML/CSS;JavaScript;Rust;SQL',
#  'Bash/Shell;Groovy;JavaScript;Python;Rust;SQL',
#  'HTML/CSS;JavaScript;PHP;Ruby',
#  'Assembly;Bash/Shell;C;C++;Go;Java;JavaScript;LISP;Lua;Python;Rust;TypeScript',
#  'Bash/Shell;Dart;Go;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
#  'Clojure;HTML/CSS;JavaScript;Kotlin;PHP;Rust;SQL',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;LISP;PowerShell;SQL',
#  'C#;HTML/CSS;JavaScript',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;OCaml;Python;Rust',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell;Java;Kotlin;Python;Rust',
#  'Bash/Shell;HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell;C;C++;Go;Haskell;HTML/CSS;JavaScript;Lua;OCaml;PHP;Python;Rust;TypeScript',
#  'HTML/CSS;Java;JavaScript;Ruby;SQL',
#  'Assembly;Bash/Shell;C;Go;Java;Julia;Python;Ruby;Rust;SQL',
#  'C++;Go;HTML/CSS;JavaScript;Kotlin;Python;TypeScript',
#  'C#;PowerShell;SQL;TypeScript',
#  'Bash/Shell;C#;C++;HTML/CSS;Perl;PHP;PowerShell;Python;Rust;SQL;VBA',
#  'Bash/Shell;C;Objective-C;Python;Rust;Swift',
#  'Bash/Shell;HTML/CSS;JavaScript;OCaml;Python;TypeScript',
#  'C;C++;HTML/CSS;Java;JavaScript;Python;TypeScript',
#  'Bash/Shell;C;HTML/CSS;JavaScript;Python;Rust;SQL',
#  'Bash/Shell;Elixir;Go;JavaScript;Rust',
#  'C#;HTML/CSS;Java;JavaScript;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Ruby;TypeScript',
#  'Java;Kotlin;Python;SQL',
#  'Bash/Shell;Go;Groovy;Python;Ruby;Swift',
#  'C#;F#;HTML/CSS;JavaScript;PowerShell;SQL',
#  'C++;HTML/CSS;Java;JavaScript;Python;R;SQL;TypeScript',
#  'C#;JavaScript;Python;Rust',
#  'C#;F#;SQL',
#  'Assembly;C;C++;HTML/CSS;JavaScript;MATLAB;Python',
#  'C++;Python',
#  'C;C++;Java;PHP;Python;Rust',
#  'Bash/Shell;Clojure;Haskell;HTML/CSS',
#  'C;C#;C++;Go;Haskell;Java;JavaScript;Kotlin;Ruby;Rust;Scala;SQL;TypeScript',
#  'C#;C++;HTML/CSS;Java;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;Python;Rust',
#  'Dart;Go;Java;JavaScript;Kotlin;TypeScript',
#  'TypeScript',
#  'C#;C++;F#;Rust;SQL',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL',
#  'Bash/Shell;C;Elixir;HTML/CSS;JavaScript;Kotlin;PHP;Rust;SQL;TypeScript',
#  'Bash/Shell;C#;Dart;HTML/CSS;Java;JavaScript;MATLAB;SQL',
#  'Bash/Shell;C#;Go;HTML/CSS;JavaScript;PowerShell;Ruby;SQL;TypeScript;VBA',
#  'Bash/Shell;C;C++;MATLAB;Python',
#  'Bash/Shell;Python;Rust;TypeScript',
#  'C++;Python;Rust',
#  'C#;F#;JavaScript',
#  'HTML/CSS;JavaScript;Python;Rust;TypeScript',
#  'Groovy;HTML/CSS;Java;JavaScript;Lua;PowerShell;Python;SQL',
#  'Bash/Shell;Groovy;Java;JavaScript;Kotlin;PHP;Python;Rust;SQL;TypeScript',
#  'Dart;HTML/CSS;JavaScript;PHP;Python;SQL;Swift',
#  'Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;LISP;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;PHP;Python;Rust;SQL',
#  'Python;SQL',
#  'Bash/Shell;Clojure;Java',
#  'C;C++;PowerShell;Python',
#  'C;C++;Kotlin;Rust',
#  'C;C++;Clojure;Go;Java',
#  'C;C++;JavaScript;Python;Rust;SQL;TypeScript',
#  'C;C#;JavaScript;SQL',
#  'C#;C++;HTML/CSS;JavaScript;PowerShell',
#  'C#;JavaScript;SQL;TypeScript',
#  'C;C++;HTML/CSS;JavaScript;MATLAB;PowerShell;Python;Rust;Solidity;SQL',
#  'C++;Rust',
#  'Bash/Shell;Go;HTML/CSS;Java;JavaScript;Lua;Perl;Python;Ruby;Rust;TypeScript',
#  'Bash/Shell;Clojure;Go;HTML/CSS;Java;JavaScript;Ruby;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;PowerShell;Python;Ruby;SQL',
#  'C#;HTML/CSS;JavaScript;PowerShell;SQL',
#  'Bash/Shell;C;C++;Go;Haskell;HTML/CSS;JavaScript;LISP;PHP;Python;Rust;SQL;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;Python;Rust;SQL',
#  'C;C++;Java;Python',
#  'Bash/Shell;Go;HTML/CSS;SQL',
#  'Clojure;Elixir;JavaScript;Ruby;TypeScript',
#  'Erlang;Go;Python',
#  'Assembly;C;C++;HTML/CSS;Java;JavaScript;Python;Rust;TypeScript',
#  'HTML/CSS;JavaScript;PHP;SQL',
#  'C;C++;Java;JavaScript;Rust;SQL',
#  'Assembly;C;C++;HTML/CSS;Java;JavaScript;Python;Ruby;Rust;TypeScript',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;TypeScript',
#  'Bash/Shell;Crystal;F#;HTML/CSS;JavaScript;Python;Rust;SQL;VBA',
#  'HTML/CSS;Java;JavaScript;PowerShell;Swift;TypeScript',
#  'HTML/CSS;Java;JavaScript;Rust;TypeScript',
#  nan,
#  'Clojure;HTML/CSS;JavaScript;Rust;SQL;TypeScript',
#  'HTML/CSS;Java;Python;SQL',
#  'HTML/CSS;JavaScript;Ruby;SQL;TypeScript',
#  'Assembly;C;C#;C++;F#;HTML/CSS;JavaScript;Lua;PHP;Python;Rust;SQL;TypeScript',
#  'C#;Java;JavaScript;SQL;TypeScript',
#  'C#;C++;Java;Python',
#  'Assembly;Bash/Shell;C;C++;Groovy;Java;JavaScript;LISP;Perl;Python;Rust;TypeScript',
#  'Bash/Shell;JavaScript;SQL;TypeScript',
#  'Bash/Shell;C;Go;HTML/CSS;JavaScript;Lua;Perl;PHP;Python;Rust;SQL',
#  'Bash/Shell;HTML/CSS;Java;Python;SQL',
#  'C;C++;Clojure;JavaScript;Python',
#  'JavaScript;SQL;TypeScript',
#  'Bash/Shell;Haskell;HTML/CSS;Java;JavaScript;Python;Rust;SQL',
#  'C;Java;Python;Rust',
#  'Go;Python;Rust',
#  'COBOL;HTML/CSS;Java;Perl;SQL',
#  'Java;JavaScript;Kotlin;Rust;SQL;TypeScript',
#  'C++;HTML/CSS;JavaScript;Lua;PHP;PowerShell;Python;Rust;SQL',
#  'Bash/Shell;C;C++;HTML/CSS;JavaScript;LISP;Python;SQL;TypeScript',
#  'Java;Kotlin',
#  'Bash/Shell;Clojure;Dart;HTML/CSS;JavaScript;SQL',
#  'Assembly;Bash/Shell;C;C#;C++;F#;Go;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;C++;Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C#;Java;Kotlin;PowerShell;Python;SQL',
#  'Bash/Shell;Elixir;HTML/CSS;JavaScript;Kotlin;Python',
#  'C;C#;C++;F#;Rust',
#  'Bash/Shell;C;C++;Go;JavaScript;Python;Rust;SQL',
#  'Assembly;C#;C++;JavaScript;Rust;TypeScript',
#  'Bash/Shell;C++;HTML/CSS;Java;JavaScript;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;Go;JavaScript;Lua;Python;Ruby;SQL;TypeScript',
#  'Go;JavaScript;Python;Rust;SQL;TypeScript',
#  'Java;JavaScript;Python;SQL;TypeScript',
#  'Python',
#  'HTML/CSS;JavaScript;Rust;SQL;TypeScript',
#  'COBOL;Rust;SQL',
#  'Bash/Shell;C++;Java;JavaScript;SQL',
#  'Bash/Shell;Clojure;Dart;HTML/CSS;JavaScript;PHP;Ruby;SQL',
#  'Clojure;Java',
#  'Bash/Shell;C#;HTML/CSS;Java;JavaScript;Rust;SQL;TypeScript',
#  'HTML/CSS;JavaScript;TypeScript',
#  'Bash/Shell;C;HTML/CSS;Java;JavaScript;Python;R;Rust;Scala;TypeScript',
#  'Bash/Shell;C#;Clojure;Go;Groovy;Java;Kotlin;Python;SQL',
#  'C;C++;JavaScript;Python;SQL',
#  'HTML/CSS;JavaScript',
#  'C#;Clojure;Elixir;F#;HTML/CSS;JavaScript;PowerShell;SQL',
#  'C++;HTML/CSS;JavaScript;Python;Rust;TypeScript',
#  'C;C++;Go;JavaScript;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C++;Go;HTML/CSS;Java;JavaScript;Python;Rust;SQL;TypeScript',
#  'Go;Java;JavaScript;Kotlin;Rust;SQL',
#  'JavaScript;Python;TypeScript',
#  'Bash/Shell;Clojure;Dart;HTML/CSS;Java;JavaScript',
#  'Go;HTML/CSS;JavaScript;PowerShell;Python;Rust;TypeScript',
#  'Bash/Shell;C++;Groovy;Java;Kotlin;PowerShell;Python',
#  'C#;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;Go;Groovy;Java;JavaScript;PHP;Python;SQL',
#  'Bash/Shell;C;C++;Elixir;Erlang;Go;Groovy;HTML/CSS;Java;JavaScript;Kotlin;Perl;Python;Ruby;Rust;SQL;TypeScript',
#  'Scala;SQL',
#  'C#;C++;Java;JavaScript;Objective-C;PowerShell;Ruby;TypeScript',
#  'Assembly;Bash/Shell;C;C++;Go;HTML/CSS;JavaScript;Python;Rust;Solidity',
#  'Groovy;HTML/CSS;Java;JavaScript;Kotlin;Python;SQL',
#  'Assembly;Bash/Shell;C;C++;PowerShell;Python;Rust',
#  'C#;JavaScript;SQL;VBA',
#  'Bash/Shell;C#;Haskell;HTML/CSS;JavaScript;TypeScript',
#  'JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell;C;Elixir;JavaScript;Rust;SQL;TypeScript',
#  'Bash/Shell;C#;JavaScript;PowerShell;Python;SQL',
#  'Java;PHP',
#  'Bash/Shell;C;C++;Delphi;HTML/CSS;JavaScript;PHP;SQL;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;Java;JavaScript;SQL',
#  'Bash/Shell;Go;Python;Rust',
#  'Bash/Shell;C;C++;Go;Java;JavaScript;Kotlin;Perl;PHP;Python;Rust;Scala;SQL;TypeScript',
#  'C++;Kotlin;MATLAB;Python;Rust',
#  'C#;JavaScript;TypeScript',
#  'Clojure;Python;Scala;SQL',
#  'Bash/Shell;Dart;Java;JavaScript;SQL',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;SQL',
#  'Bash/Shell;JavaScript;PHP;Python;SQL;TypeScript',
#  'C#;JavaScript;PowerShell;SQL;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'C;C++;Haskell;Python;Rust',
#  'Bash/Shell;C;C++;Go;HTML/CSS;Ruby;Rust;SQL',
#  'Bash/Shell;C++;Clojure;Elixir;Go;Julia;LISP;OCaml;Python;Ruby;Rust;Scala;TypeScript',
#  'C;C#;C++;Clojure;Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;C++;Python;SQL;Swift',
#  'Bash/Shell;JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell;C++;HTML/CSS;Java;JavaScript;Julia;Python;SQL',
#  'Bash/Shell;C;C#;C++;Haskell;Python;SQL',
#  'HTML/CSS;JavaScript;SQL',
#  'JavaScript;PHP',
#  'Assembly;Bash/Shell;C++;HTML/CSS;JavaScript;MATLAB;Objective-C;Python;TypeScript',
#  'Bash/Shell;JavaScript;Python;Rust',
#  'C#;HTML/CSS;Java;SQL',
#  'C;C++;JavaScript;Python;Rust',
#  'Assembly;Bash/Shell;C;C++;LISP;PowerShell;Python',
#  'Bash/Shell;C;C++;HTML/CSS',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;PHP;SQL',
#  'Bash/Shell;C++;Go;Rust;SQL',
#  'Assembly;Bash/Shell;C;C++;Elixir;Go;Groovy;PowerShell;Python;Rust',
#  'C#;HTML/CSS;SQL',
#  'Clojure;JavaScript;SQL;TypeScript',
#  'Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Kotlin;PHP;Python;SQL',
#  'C;Haskell;Ruby',
#  'C;C#;C++;HTML/CSS;JavaScript;Python;Rust',
#  'Bash/Shell;Java;JavaScript;PHP;Rust;SQL;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;Java;JavaScript;Python;SQL',
#  'Assembly;Bash/Shell;C++;HTML/CSS;Java;JavaScript;PowerShell;Python;SQL',
#  'Bash/Shell;Groovy;Java;Python;TypeScript',
#  'Bash/Shell;C#;C++;HTML/CSS;JavaScript;Python;Rust',
#  'C#;Java;Ruby',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Python',
#  'Bash/Shell;C++;HTML/CSS;Java;JavaScript;Kotlin;Lua;Python;Ruby;Scala;SQL;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;Rust;TypeScript',
#  'Bash/Shell;Python;Rust',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Ruby;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;Python;SQL',
#  'C;C++;Groovy;HTML/CSS;JavaScript;Lua;Python;Rust;SQL',
#  'Assembly;Bash/Shell;C#;HTML/CSS;Java;JavaScript;PowerShell;Python;R;Rust;TypeScript',
#  'C#;C++;Rust',
#  'C;C#;C++;Python;SQL',
#  'C;C#;C++;JavaScript;Lua',
#  'Go;Rust',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;OCaml;Python;Rust;SQL',
#  'Bash/Shell;Go;Groovy',
#  'Bash/Shell;Go;Java;JavaScript;Python;TypeScript',
#  'C;C++;Python;SQL',
#  'Go;Java;JavaScript;TypeScript',
#  'HTML/CSS;Java;Rust;SQL',
#  'HTML/CSS;PHP;TypeScript',
#  'C#;Go;JavaScript;Kotlin;TypeScript',
#  'HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL',
#  'Bash/Shell;Dart;Go;Groovy;HTML/CSS;Java;JavaScript;Perl;Python;SQL',
#  'Java;Kotlin;PHP',
#  'JavaScript;Ruby;Rust;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Kotlin;Lua;Python;TypeScript',
#  'Bash/Shell;C;Go;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'C#;PowerShell;SQL',
#  'Bash/Shell;C;C++;Go;Rust',
#  'Bash/Shell;C;C#;C++;HTML/CSS;Java;JavaScript;LISP;Python;R;Ruby;Rust;Scala;SQL;TypeScript',
#  'HTML/CSS;Java;JavaScript;TypeScript',
#  'HTML/CSS;JavaScript;OCaml;Rust;SQL;TypeScript',
#  'Bash/Shell;Clojure;Go;HTML/CSS;JavaScript;Kotlin;Python;SQL;Swift;TypeScript',
#  'Bash/Shell;C;C++;HTML/CSS;MATLAB;Python',
#  'Bash/Shell;C;Clojure;Java;JavaScript;SQL',
#  'C++;MATLAB',
#  'C++;JavaScript;Perl;TypeScript',
#  'Bash/Shell;C;C++;Crystal;Dart;Elixir;Go;Haskell;HTML/CSS;Java;JavaScript;Kotlin;LISP;MATLAB;Perl;Python;Ruby;Rust;TypeScript',
#  'Go;HTML/CSS;JavaScript;Kotlin;TypeScript',
#  'Bash/Shell;C#;Groovy;Java;JavaScript;PowerShell;SQL',
#  'Bash/Shell;C#;F#;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Java;SQL',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;PHP;TypeScript',
#  'C++;HTML/CSS;JavaScript;Python;Rust',
#  'Bash/Shell;Java;Python;Scala',
#  'Haskell;HTML/CSS;Java;JavaScript;Kotlin;TypeScript',
#  'Bash/Shell;Elixir;Haskell;Python;Rust;Scala;SQL',
#  'Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;Python;TypeScript',
#  'C#;Go;HTML/CSS;JavaScript;PowerShell;Rust;SQL;TypeScript',
#  'Bash/Shell;Python;Rust;SQL',
#  'Bash/Shell;OCaml',
#  'Bash/Shell;Elixir;HTML/CSS;PowerShell;Python',
#  'Assembly;Bash/Shell;C;C++;Fortran;Go;Java;Python;Ruby;Rust',
#  'Elixir;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Clojure;Java;JavaScript;SQL',
#  'Java;JavaScript;Lua;SQL;TypeScript',
#  'Bash/Shell;Go;JavaScript;SQL;TypeScript',
#  'Bash/Shell;C#;Python',
#  'Bash/Shell;Java;JavaScript;Kotlin;Python;SQL;TypeScript',
#  'C;C++;Rust',
#  'Bash/Shell;C#;Java;JavaScript',
#  'Bash/Shell;Groovy;Java;SQL',
#  'Bash/Shell;C;C++;Go;MATLAB;Python;Rust;Scala;SQL',
#  'Java;Lua;Rust;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Bash/Shell;C;C++;Go;Python;Rust',
#  'C;C++;HTML/CSS;Java;JavaScript;PHP;Python;Ruby;TypeScript;VBA',
#  'JavaScript;PHP;Python',
#  'Bash/Shell;C;C++;Elixir;Go;JavaScript;Rust;TypeScript',
#  'Assembly;Bash/Shell;C;C++;PowerShell;Rust',
#  'Java;Kotlin;VBA',
#  'Groovy;Java',
#  'JavaScript;PHP;TypeScript',
#  'Bash/Shell;C;C++;Java;JavaScript;Python;Rust;SQL',
#  'C#;Crystal;Java;Python;SQL',
#  'Bash/Shell;Java;JavaScript;Kotlin;PHP;Python;TypeScript',
#  'Bash/Shell;C++;MATLAB;Python',
#  'Dart;Go;HTML/CSS;Java;JavaScript;TypeScript',
#  'Bash/Shell;Java;JavaScript;Kotlin;Python;Rust;TypeScript',
#  'Bash/Shell;C#;JavaScript;Python;Ruby;Scala;SQL',
#  'Groovy;Java;JavaScript;Python;TypeScript',
#  'Bash/Shell;C;C#;C++;Delphi;Java;JavaScript;Perl;PHP;Ruby;SQL',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;JavaScript;Python;TypeScript',
#  'Bash/Shell;C;C#;Go;HTML/CSS;JavaScript;Python;Rust;SQL;Swift;TypeScript',
#  'Assembly;Bash/Shell;C;Julia;Python;Rust;TypeScript',
#  'C;C++;Elixir;Go;LISP;Ruby;Rust;SQL',
#  'Bash/Shell;C#;Go;JavaScript;PowerShell;SQL;TypeScript',
#  'Bash/Shell;C;C#;C++;HTML/CSS;JavaScript;Lua;PowerShell;Python;Rust;TypeScript',
#  'Assembly;C;C++',
#  'C++;Groovy;HTML/CSS;JavaScript;Python',
#  'HTML/CSS;Java;JavaScript;Kotlin',
#  'HTML/CSS;JavaScript;Rust;TypeScript',
#  'C;C++;Python;Rust',
#  'Assembly;C;C#;C++;HTML/CSS;MATLAB',
#  'C++;Java;Python;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Rust;Swift;TypeScript',
#  'C++;Go;Java;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;PHP;Python;Rust;TypeScript',
#  'C++;Go;Python;Rust',
#  'C;C++;Java;Objective-C',
#  'Bash/Shell;C;C#;Go;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;PowerShell;Python;SQL;Swift;TypeScript',
#  'C#;Java;PowerShell',
#  'Assembly;C;C++;HTML/CSS;Java;JavaScript;PHP;Python;Rust;SQL',
#  'Clojure;HTML/CSS;LISP',
#  'Assembly;C;C++;Java',
#  'C;C++;Lua;Python;Rust',
#  'C#;HTML/CSS;JavaScript;SQL;TypeScript;VBA',
#  'Bash/Shell;Clojure;HTML/CSS;JavaScript;PHP;SQL',
#  'C;JavaScript;Rust',
#  'Bash/Shell;C#;C++;Go;Python;SQL',
#  'C#;HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript',
#  'Bash/Shell;Go;Java;JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell;C;Java;Kotlin;Perl;Python;Rust;SQL',
#  'Bash/Shell;Clojure;HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell;C;C#;Python',
#  'Go;JavaScript;SQL;TypeScript',
#  'Bash/Shell;C;C++;Java;JavaScript;Julia;Kotlin;MATLAB;Python;Rust;TypeScript',
#  'Dart;HTML/CSS;JavaScript;Objective-C;SQL;Swift;TypeScript',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;JavaScript;PHP;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Lua;Rust;TypeScript',
#  'Java;JavaScript;Python;SQL',
#  'Clojure;Python',
#  'Bash/Shell;Clojure;SQL',
#  'Assembly;Bash/Shell;C;C++;Go;Lua;Objective-C;Python;Rust;SQL;Swift',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;Lua;PHP;Python;Rust;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;Python',
#  'C;C#;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript;VBA',
#  'Bash/Shell;Go;Groovy;HTML/CSS;Java;JavaScript;Python',
#  'Elixir;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C#;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;PHP;Python;Rust;SQL',
#  'Bash/Shell;C#;Clojure;HTML/CSS;JavaScript;Python;SQL',
#  'Clojure;Java;JavaScript;Rust;TypeScript',
#  'Elixir;Erlang;JavaScript;Python',
#  'C#;HTML/CSS;PowerShell;SQL;TypeScript',
#  'Clojure;Java;Solidity;SQL',
#  'Bash/Shell;C++;HTML/CSS;JavaScript',
#  'HTML/CSS;Java;JavaScript;SQL;TypeScript;VBA',
#  'Assembly;Bash/Shell;C#;JavaScript;PowerShell;Python;Rust;SQL',
#  'Bash/Shell;Go;Groovy;JavaScript;Kotlin;Rust;TypeScript',
#  'Assembly;Bash/Shell;C;C#;C++;Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Rust;TypeScript',
#  'Assembly;Bash/Shell;Crystal;HTML/CSS;Java;JavaScript;Python;Ruby;SQL',
#  'Assembly;Bash/Shell;C;C++;Groovy;HTML/CSS;JavaScript;MATLAB;PHP;PowerShell;Python;Ruby',
#  'Assembly;C;Go;Java;PowerShell;Rust',
#  'Go;Java;PHP;Ruby;Rust',
#  'Elixir;Erlang;F#;HTML/CSS;JavaScript;Python;Ruby;Rust;SQL;TypeScript',
#  'C;C#;C++;Dart;Go;Java',
#  'Bash/Shell;C;C++;Elixir;Haskell;HTML/CSS;JavaScript;PHP;Ruby;Rust;TypeScript',
#  'C#;JavaScript;SQL',
#  'Bash/Shell;C;C++;Fortran;PowerShell;Python',
#  'Assembly;Bash/Shell;C;PowerShell;Python',
#  'C#;HTML/CSS;JavaScript;SQL;VBA',
#  'Bash/Shell;Clojure;Groovy;Java;JavaScript;Ruby;SQL',
#  'Bash/Shell;C#;HTML/CSS;Java;JavaScript;PowerShell;Python;SQL',
#  'C#;Crystal;HTML/CSS;PowerShell;SQL;VBA',
#  'Bash/Shell;Java;JavaScript;TypeScript',
#  'Go;Groovy;Java;Python;SQL',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;Kotlin;Lua;PHP;Python;SQL',
#  'C;Go;Lua;Python',
#  'Clojure;SQL;TypeScript',
#  'Bash/Shell;Java;JavaScript;Kotlin;TypeScript',
#  'HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'Bash/Shell;C#;SQL',
#  'Java;JavaScript;Python;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Ruby;SQL;TypeScript',
#  'C;C++;Python',
#  'Clojure;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'HTML/CSS;PHP',
#  'Assembly;C;C#;C++;Go;HTML/CSS;JavaScript;Lua;Python;Rust;Swift;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;PowerShell;R;Rust;SQL;TypeScript',
#  'Bash/Shell;C++;HTML/CSS;Java;Python;SQL',
#  'Bash/Shell;Go;HTML/CSS;Java;JavaScript;Solidity;TypeScript',
#  'Go;JavaScript;Perl;Python;Ruby;SQL;TypeScript',
#  'Bash/Shell;C++;JavaScript;Python;Rust;TypeScript',
#  'Java;Python;Rust',
#  'C;C#;HTML/CSS;JavaScript;Objective-C;PowerShell;Python;SQL;Swift;TypeScript',
#  'Bash/Shell;C++;Go;Java;JavaScript;Kotlin;PowerShell;Rust;SQL',
#  'Clojure;JavaScript;Python;SQL;TypeScript',
#  'C#;JavaScript;Lua;PowerShell;Python;Ruby;Rust',
#  'C#;C++;HTML/CSS;JavaScript;PowerShell;Python;SQL;VBA',
#  'Bash/Shell;HTML/CSS;JavaScript;Lua;Ruby;SQL;TypeScript',
#  'PHP',
#  'Assembly;C;C++;Perl;Python;Rust',
#  'Bash/Shell;C#;JavaScript;SQL',
#  'JavaScript;Rust;SQL;Swift;TypeScript',
#  'Bash/Shell;C#;C++;Go;Java;PowerShell;Python;Scala;SQL;VBA',
#  'Assembly;Bash/Shell;C;HTML/CSS;Java;JavaScript;Objective-C;Python;R;Rust;Solidity;SQL;Swift;TypeScript;VBA',
#  'Bash/Shell;Haskell;HTML/CSS;PowerShell;Python;SQL;TypeScript',
#  'JavaScript;Rust',
#  'HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Clojure;JavaScript',
#  'Assembly;C;C#;C++;Lua;Python;Rust;SQL',
#  'Assembly;C;C++;Go;Java;Rust',
#  'HTML/CSS;Java;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;Go;HTML/CSS;LISP;Lua;SQL',
#  'Elixir;Python;Rust;SQL',
#  'Bash/Shell;Go;Java;JavaScript;Kotlin;SQL',
#  'Python;R;Rust',
#  'APL;Java;JavaScript;Kotlin;Python',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;LISP;PowerShell;SQL;TypeScript',
#  'HTML/CSS;JavaScript;Kotlin;Objective-C;PHP;Python;R;SQL;Swift;TypeScript',
#  'HTML/CSS;JavaScript;PHP;Rust;SQL;TypeScript',
#  'Dart;HTML/CSS;JavaScript;SQL;TypeScript',
#  'C;Clojure;PowerShell;Rust',
#  'C;C++;SQL',
#  'HTML/CSS;JavaScript;PHP;Python;TypeScript',
#  'Clojure',
#  'C;C#;Rust',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Lua;Rust;SQL;TypeScript',
#  'JavaScript;PHP;Python;SQL',
#  'Assembly;Bash/Shell;C;C++;Dart;Java;JavaScript;Lua;PowerShell;Python;SQL',
#  'Go;HTML/CSS;JavaScript;Objective-C;Ruby;TypeScript',
#  'C#;HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript',
#  'LISP;Python;R',
#  'C;Python;Rust',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'C#;Dart;JavaScript;SQL;TypeScript',
#  'C#;JavaScript;Python;Rust;TypeScript',
#  'Assembly;Bash/Shell;C;C#;C++;Elixir;HTML/CSS;Java;JavaScript;Lua;PowerShell;Python;Rust;Scala;SQL;TypeScript',
#  'Bash/Shell;C#;JavaScript;TypeScript',
#  'Assembly;HTML/CSS;JavaScript;Python',
#  'Bash/Shell;C++;HTML/CSS;Java;JavaScript;PowerShell;Python;Ruby;Rust;SQL',
#  'JavaScript;Rust;TypeScript',
#  'C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript',
#  'Bash/Shell;C++;Go;HTML/CSS;JavaScript;TypeScript',
#  'Go;Python;Rust;SQL',
#  'HTML/CSS;Java;JavaScript;PHP;Python;SQL',
#  'C#;Go;SQL',
#  'Assembly;Bash/Shell;C;C#;C++;HTML/CSS;JavaScript;Objective-C;PowerShell;Python;Rust;SQL;Swift;TypeScript;VBA',
#  'C#;Java;JavaScript',
#  'C#;Python;Rust',
#  'Bash/Shell;C;C++;JavaScript;Objective-C;Rust;Swift',
#  'C;JavaScript;Julia;Python;Rust;SQL',
#  'Java;TypeScript',
#  'Bash/Shell;Elixir;HTML/CSS;Kotlin;Python;SQL;TypeScript',
#  'HTML/CSS;Java;JavaScript;Kotlin;Rust;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;Lua;Python;Rust',
#  'Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Dart;HTML/CSS;JavaScript;SQL',
#  'Assembly;Bash/Shell;C;C++;Python',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;SQL;TypeScript',
#  'C#;Dart;F#;Lua;PowerShell;SQL',
#  'Java;PowerShell',
#  'HTML/CSS;Java;JavaScript;Kotlin;Python',
#  'Bash/Shell;C#;F#;Go;Groovy;Haskell;Java;JavaScript;Kotlin;PowerShell;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;Java;JavaScript;PowerShell;TypeScript',
#  'Bash/Shell;C;C++;Fortran',
#  'Bash/Shell;C;Rust',
#  'Bash/Shell;Elixir;Erlang;HTML/CSS;JavaScript;Kotlin;Python;TypeScript',
#  'C++;HTML/CSS;JavaScript;TypeScript',
#  'Bash/Shell;Go;Groovy;Python;R;Ruby;SQL',
#  'Dart;Swift',
#  'C;C#;C++;F#;Go;JavaScript;PowerShell;Rust;TypeScript',
#  'Bash/Shell;Groovy;HTML/CSS;Java;JavaScript',
#  'HTML/CSS;Java;JavaScript;SQL',
#  'Bash/Shell;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#  'C#;Dart;HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeScript',
#  'C;C++;HTML/CSS;Java;JavaScript;Python;Rust;TypeScript',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;JavaScript;Lua;Python;SQL',
#  'Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;Python;Ruby;Rust;SQL;TypeScript',
#  'HTML/CSS;JavaScript;Lua;PHP;Python;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;Python;SQL',
#  'F#',
#  'Bash/Shell;C;Java;Python;SQL',
#  'C#;HTML/CSS;JavaScript;Python;TypeScript',
#  'PowerShell;Python;R;SQL',
#  'Bash/Shell;Clojure;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Go;HTML/CSS;JavaScript;Ruby;TypeScript',
#  'Bash/Shell;C;Java;Rust;SQL',
#  'Bash/Shell;C;C#;C++;Lua',
#  'PHP;Python;SQL',
#  'HTML/CSS;JavaScript;Perl;Python;SQL;TypeScript',
#  'Assembly;C;C++;JavaScript;MATLAB;Python;R',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;LISP;Lua;MATLAB;OCaml;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;Rust;SQL;TypeScript',
#  'Bash/Shell;Go',
#  'Go;JavaScript;Python;Rust;SQL',
#  'Assembly;Bash/Shell;Elixir;Go;Haskell;HTML/CSS;JavaScript;Julia;OCaml;Perl;PowerShell;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C;Go;HTML/CSS;JavaScript;Lua;Perl;Python',
#  'Bash/Shell;Go;Groovy;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;Rust;SQL;TypeScript',
#  'C++;Elixir;Go;PHP;Ruby;Scala',
#  'Assembly;Bash/Shell;C;C#;Elixir;Haskell;HTML/CSS;JavaScript;OCaml;Python;Rust;Scala',
#  'HTML/CSS;JavaScript;PHP;SQL;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'C;C#;Go;JavaScript;Python;SQL',
#  'Bash/Shell;C#;C++;SQL',
#  'C#;Dart;Java',
#  'C++;Elixir;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Go;Java;Kotlin;Objective-C;SQL;Swift',
#  'Assembly;Bash/Shell;C;C++;Java;Python',
#  'Bash/Shell;Groovy;JavaScript;Python;Ruby;SQL',
#  'Java;JavaScript',
#  'C#;HTML/CSS;Java;PowerShell;SQL;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL',
#  'Elixir;Go;HTML/CSS;Java;JavaScript;Rust;SQL',
#  'Assembly;C#;C++;HTML/CSS;Java;JavaScript;Lua;Python;Rust',
#  'APL;Assembly;Bash/Shell;C;C#;C++;Go;HTML/CSS;Java;JavaScript;LISP;Perl;Python;R;Ruby;SQL',
#  'COBOL;Java;JavaScript;SQL',
#  'Assembly;Bash/Shell;C;C++;Dart;HTML/CSS;Java;JavaScript;Julia;LISP;Lua;MATLAB;Objective-C;Python;Rust;SQL;Swift',
#  'JavaScript;Ruby;SQL;TypeScript',
#  'Bash/Shell;Python',
#  'Assembly;Bash/Shell;C;C#;C++;Clojure;COBOL;Go;HTML/CSS;Java;JavaScript;Kotlin;Lua;Perl;PHP;PowerShell;Python;Ruby;Rust;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#  'Go;HTML/CSS;JavaScript;Kotlin;Rust;TypeScript',
#  'Go;HTML/CSS;JavaScript;PHP;SQL;TypeScript',
#  'Java;JavaScript;Python;Ruby;Scala;SQL',
#  'Go;JavaScript;Objective-C;Python;Rust;Swift',
#  'Assembly;Bash/Shell;C;C++;Go',
#  'C++;Python;Rust;SQL',
#  'Assembly;C;C#;C++;Java;MATLAB;PowerShell;Python;Rust;Swift',
#  'Assembly;C;C#;C++;JavaScript;Rust',
#  'Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL',
#  'Assembly;C;C++;JavaScript;PHP;Python;SQL',
#  'Bash/Shell;C;C++;Java;JavaScript;Julia;Rust;TypeScript',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;Python',
#  'C;C#;C++;Java;JavaScript;Python',
#  'C#;F#;HTML/CSS;Java;JavaScript;PHP;Python;Rust;SQL',
#  'C;C#;C++;Java;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C++;Go;Lua;Python;Rust',
#  'Bash/Shell;Haskell;HTML/CSS;Objective-C;Rust',
#  'Assembly;Bash/Shell;C;C++;Haskell;HTML/CSS;Java;JavaScript;LISP',
#  'C#;HTML/CSS;JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell;C;C++;Lua;Python;Rust',
#  'Python;R;SQL',
#  'C++',
#  'Assembly;Bash/Shell;C;C++;PowerShell;Python',
#  'Go;Java;Python',
#  'Scala',
#  'C;Go;Perl;Python;R;Rust',
#  'C++;Elixir;JavaScript;Ruby',
#  'Bash/Shell;Go;HTML/CSS;Java;JavaScript;Python',
#  'Bash/Shell;Go;Rust;SQL',
#  'HTML/CSS;JavaScript;SQL;TypeScript',
#  'Bash/Shell;Erlang;Go;Python;Rust;SQL',
#  'Bash/Shell;C#;Elixir;HTML/CSS;JavaScript;Kotlin;Ruby;SQL',
#  'C#;HTML/CSS;JavaScript;Rust;TypeScript',
#  'Bash/Shell;Python;R',
#  'Bash/Shell;Go;Ruby;Rust;TypeScript',
#  'C#;HTML/CSS;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Julia;Python;Rust',
#  'Assembly;C;C++;Lua;Python',
#  'C#;HTML/CSS;JavaScript;SAS;SQL;TypeScript',
#  'C;C#;C++;HTML/CSS;Python;Rust',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Ruby;Rust;SQL;TypeScript',
#  'HTML/CSS;Java;JavaScript;Python;Ruby;SQL;Swift;TypeScript',
#  'C#;Go;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'C#;JavaScript',
#  'Bash/Shell;HTML/CSS;JavaScript;TypeScript',
#  'Java;JavaScript;TypeScript',
#  'C;C++;JavaScript;MATLAB;Python;Rust',
#  'Java;LISP;Python;Rust;Swift',
#  'Bash/Shell;TypeScript',
#  'Assembly;Bash/Shell;LISP',
#  'HTML/CSS;Java;Python;Rust;TypeScript',
#  'Assembly;Bash/Shell;C;C++;Dart;Go;Groovy;Haskell;Java;JavaScript;Objective-C;Python;Rust;Scala;Swift;TypeScript',
#  'Bash/Shell;C;C++;Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript',
#  'C;C#;C++;JavaScript;TypeScript',
#  'Bash/Shell;C#;Elixir;Erlang;Go;HTML/CSS;JavaScript;Lua;Python;Rust;SQL;Swift;TypeScript',
#  'C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell;C;C#;F#;HTML/CSS;Java;JavaScript;PowerShell;Rust;SQL;TypeScript',
#  'C;HTML/CSS;Java;Kotlin;Lua;Python;Rust;Scala',
#  'Dart;HTML/CSS;Java;JavaScript;Kotlin;Python;Swift;TypeScript',
#  'Java;Kotlin;Python;Ruby;SQL',
#  'C;C#;HTML/CSS;JavaScript;PHP;Rust;TypeScript',
#  'Bash/Shell;C;Python;SQL',
#  'HTML/CSS;JavaScript;PHP;Python;Rust;SQL',
#  'Bash/Shell;Go;Groovy;Java;Kotlin;Python',
#  'Assembly;Bash/Shell;C;C++;Python;Rust',
#  'Java',
#  'Bash/Shell;C++;Java;Kotlin;Python;Rust',
#  'Bash/Shell;Clojure;Java;JavaScript;Lua;TypeScript',
#  'Bash/Shell;Go;Java;JavaScript;Python;Ruby;Scala;SQL;TypeScript',
#  'Bash/Shell;Crystal;Go;HTML/CSS;JavaScript;Ruby;Rust;SQL',
#  'Bash/Shell;Go;Groovy;HTML/CSS;JavaScript;Python;SQL;Swift',
#  'Bash/Shell;C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;Ruby;Rust;SQL;TypeScript',
#  'Dart;Go;Groovy;HTML/CSS;Java;JavaScript;Kotlin;Rust;TypeScript',
#  'Bash/Shell;C;Dart;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;Python;Rust;SQL;Swift;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Ruby;SQL;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PHP;PowerShell;Rust;SQL;Swift;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;PHP',
#  'Assembly;Bash/Shell;C;C++;Go;Haskell;JavaScript;Python;Rust;TypeScript',
#  'C;C#;C++;PowerShell;Python;Rust',
#  'Clojure;F#;Java;Python;SQL',
#  'Bash/Shell;C;C++;Clojure;Go;HTML/CSS;Python;Ruby;Rust;Solidity',
#  'Bash/Shell;C;Perl;Python;Rust',
#  'C#;Python',
#  'C#;Go;JavaScript;Rust;SQL;TypeScript',
#  'C#;HTML/CSS;Python;SQL;TypeScript',
#  'Java;Kotlin;Python;Ruby;Rust;SQL;TypeScript',
#  'Bash/Shell;Kotlin;TypeScript',
#  'HTML/CSS;JavaScript;Python',
#  'C;Java;JavaScript;Kotlin;Objective-C;Python;Swift',
#  'Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Ruby;SQL',
#  'Bash/Shell;C++;Haskell;HTML/CSS;Python;Rust;SQL',
#  'Bash/Shell;C#;MATLAB;PowerShell',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;C;C#;Go;Java;JavaScript;PowerShell',
#  'Java;Ruby;TypeScript',
#  'Bash/Shell;C#;Go;JavaScript;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;TypeScript',
#  'Bash/Shell;Go;Java;JavaScript;Kotlin;Python;Rust;Scala;SQL',
#  'HTML/CSS;Java;JavaScript;Ruby;Rust;SQL;TypeScript',
#  'Bash/Shell;Erlang;JavaScript;Python;Rust;SQL',
#  'Assembly;Bash/Shell;C;HTML/CSS;JavaScript;Julia;MATLAB;PHP;PowerShell;Python;R;SQL',
#  'Assembly;Bash/Shell;HTML/CSS;Java;JavaScript;Python;Rust;Scala;SQL;TypeScript',
#  'JavaScript;Ruby;SQL',
#  'Bash/Shell;Groovy;HTML/CSS;Java;Kotlin;Python;SQL',
#  'Bash/Shell;Dart;HTML/CSS;JavaScript;Python;R;Rust;SQL;TypeScript',
#  'HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;C;C#;Go;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C++;Go;Perl;Python;R;Rust;Scala;SQL',
#  'Assembly;Bash/Shell;C;Python;Rust',
#  'C++;HTML/CSS;JavaScript',
#  'Bash/Shell;C;C++;Elixir;Go;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;Perl;PHP;Python;R;Ruby;Rust;SQL;Swift;TypeScript',
#  'Assembly;Bash/Shell;C++;Go;HTML/CSS;JavaScript;Python;R;Ruby;Rust;SQL',
#  'C#;Dart;HTML/CSS;Java;JavaScript;PHP;PowerShell;SQL;TypeScript',
#  'C#;Go;HTML/CSS;JavaScript;PowerShell;SQL',
#  'C;C++;Python;Rust;SQL',
#  'Bash/Shell;C;C++;PHP;PowerShell;Python;Rust',
#  'Groovy;Java;JavaScript;Python;Rust;Scala;TypeScript',
#  'Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;Python;Ruby;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;PHP;SQL',
#  'Bash/Shell;Elixir;Go;Rust',
#  'Bash/Shell;C;C++;Go;HTML/CSS;Java;JavaScript;Julia;Kotlin;PowerShell;Python;SQL',
#  'C++;Java;Lua;Rust;SQL',
#  'Go;HTML/CSS;JavaScript;PHP;Ruby;SQL',
#  'C++;Dart;HTML/CSS;JavaScript;Kotlin;TypeScript',
#  'Go;Java;Python;Rust;SQL',
#  'Bash/Shell;C++;Python;Rust;Scala',
#  'C#;F#;Fortran;Haskell;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;C++;Groovy;HTML/CSS;Java;JavaScript;Perl;Python;Rust;SQL',
#  'C;C++;Fortran;Java;Python;Scala',
#  'Go;JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell;Go;Groovy;Java;PowerShell;Rust;SQL;TypeScript',
#  'Elixir;JavaScript;Kotlin;Python;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;C#;Groovy;Java;JavaScript;PowerShell;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;PHP;Rust;SQL',
#  'Bash/Shell;JavaScript;Julia;Python;SQL',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;Kotlin;PowerShell;SQL;Swift',
#  'F#;JavaScript;Julia;Python;Rust;TypeScript',
#  'Bash/Shell;C++;Go;PHP;Rust;SQL;Swift',
#  'Julia',
#  'Bash/Shell;C;C++;JavaScript;Python',
#  'C#;Go;HTML/CSS;Python;Ruby;SQL',
#  'Go;HTML/CSS;Java;JavaScript;Kotlin;Python;SQL;TypeScript',
#  'Bash/Shell;C;C++;Go;Julia;Python;Rust',
#  'Bash/Shell;Elixir;Go;Lua',
#  'Bash/Shell;Go;Java;JavaScript;Kotlin;PowerShell;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;Java;Python;Rust;Scala;SQL',
#  'Assembly;Bash/Shell;C;C#;C++;Groovy;Objective-C;Python',
#  'Bash/Shell;C;C++;Java;Rust;TypeScript',
#  'C#;HTML/CSS;JavaScript;MATLAB;Python;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;SQL',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Rust;Solidity;SQL;Swift;TypeScript',
#  'Bash/Shell;Python;SQL',
#  'C#;C++',
#  'Kotlin;SQL',
#  'Assembly;Bash/Shell;C;C++;Go;HTML/CSS;JavaScript;OCaml;Python;Rust;TypeScript',
#  'C#;PowerShell;Python',
#  'Dart;JavaScript;Objective-C;Swift',
#  'C;C#;HTML/CSS;Java;Rust;TypeScript',
#  'C;C#;C++;Go;Haskell;HTML/CSS;JavaScript;Objective-C;Python;Rust;Swift',
#  'C++;Kotlin',
#  'Bash/Shell;Go;JavaScript;Lua;Perl;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;C#;C++;Groovy;Java;MATLAB;PowerShell;Rust',
#  'C;C#;PowerShell;Python;Rust',
#  'Java;JavaScript;PowerShell;Python;Rust;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Python;Rust;SQL;Swift',
#  'Assembly;Bash/Shell;C++;Go;HTML/CSS;LISP;Python;SQL',
#  'Assembly;Bash/Shell;C;C++;Java;JavaScript;MATLAB;Python;Rust;SQL',
#  'Bash/Shell;C;C#;HTML/CSS;Java;JavaScript;Lua;Python;SQL',
#  'Bash/Shell;C;C++;Erlang;Groovy;Kotlin;Python;Rust',
#  'Java;Python;Rust;TypeScript',
#  'Bash/Shell;Go;JavaScript;Python;SQL',
#  'Groovy;Kotlin',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Perl;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell;C;C#;C++;Crystal;Dart;Elixir;Erlang;Go;Groovy;Haskell;HTML/CSS;Java;JavaScript;Kotlin;Lua;OCaml;Perl;PHP;PowerShell;Python;Ruby;Rust;Scala;SQL;TypeScript;VBA',
#  'C#;Clojure',
#  'C#;HTML/CSS;JavaScript;Perl;Python;SQL',
#  'Bash/Shell;JavaScript;LISP;Rust;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;Lua;Rust;TypeScript',
#  'C;C++;Java;Python;Rust',
#  'C++;Ruby',
#  'Assembly;Bash/Shell;C;HTML/CSS;JavaScript;Lua;Perl;R;Ruby',
#  'C#;JavaScript;PowerShell;Rust;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Perl;Python;R;SQL',
#  'C++;JavaScript;Rust;SQL;Swift',
#  'Bash/Shell;C;C#;C++;HTML/CSS;JavaScript;Python;Rust;SQL',
#  'Go;Python',
#  'Bash/Shell;HTML/CSS;Python;Rust',
#  'Bash/Shell;Go;JavaScript;Python;Rust;Scala;SQL;TypeScript',
#  'PowerShell;Python;Rust;SQL',
#  'C#;Dart;HTML/CSS;JavaScript',
#  'JavaScript;Python;R;Rust;Scala',
#  'HTML/CSS;Java;JavaScript;Python;TypeScript',
#  'Elixir;HTML/CSS;JavaScript;Rust;TypeScript',
#  'Crystal;Kotlin;Ruby;TypeScript',
#  'Assembly;Bash/Shell;C;C#;C++;Go;HTML/CSS;Java;JavaScript;MATLAB;PowerShell;Python;Rust;SQL;TypeScript;VBA',
#  'Julia;Python;R;SQL',
#  'Dart;Go;JavaScript;Ruby;TypeScript',
#  'Go;JavaScript;Rust;TypeScript',
#  'C#;C++;HTML/CSS;JavaScript;Rust',
#  'Bash/Shell;C#;Dart;Go;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript',
#  'C++;Go;HTML/CSS;JavaScript;Julia;Lua;Python;Rust;SQL',
#  'Assembly;Bash/Shell;C;Go;Java;Kotlin;Python;Rust;SQL',
#  'Assembly;C++;JavaScript;Python;Rust;SQL',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Rust;TypeScript',
#  'Bash/Shell;Fortran;Go;JavaScript;Lua;Python;Rust;Swift;TypeScript',
#  'Bash/Shell;Kotlin;Python;Rust',
#  'HTML/CSS;Java;JavaScript;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C++;Python;Rust',
#  'Bash/Shell;Groovy;Java',
#  'Bash/Shell;COBOL;Go;HTML/CSS;JavaScript;PHP;Python;Rust;SQL;TypeScript',
#  'Go;HTML/CSS;Python;Rust;SQL;TypeScript',
#  'Elixir;JavaScript;PHP;Python;Ruby;Rust;TypeScript',
#  'Bash/Shell;Clojure;Go;Java;Kotlin;Python;Rust;SQL;TypeScript',
#  'JavaScript;Python;Scala;SQL;TypeScript',
#  'Clojure;Dart',
#  'C;C++;Go;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;Rust;SQL',
#  'Bash/Shell;C++;Python;R',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;Lua;PowerShell;Python;Ruby;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript',
#  'Bash/Shell;C;Go;Java;Python;Rust;SQL',
#  'Bash/Shell;C;C++;Go;HTML/CSS;Python;Rust',
#  'C#;VBA',
#  'Bash/Shell;C;C++;Go;Haskell;Java;JavaScript;Python;Rust;SQL',
#  'Bash/Shell;C;C++;Go;Java;JavaScript;PHP;Rust;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;PowerShell;Rust;SQL;TypeScript',
#  'Bash/Shell;Go;JavaScript;Solidity;SQL;TypeScript',
#  'C++;HTML/CSS;JavaScript;Solidity;TypeScript',
#  'Assembly;C;C++;Clojure;Dart;Elixir;HTML/CSS;Java;JavaScript;LISP;Python;Ruby',
#  'Java;SQL;VBA',
#  'Bash/Shell;C#;JavaScript;LISP;Lua;Rust;SQL;TypeScript',
#  'Bash/Shell;C++;Go;Python',
#  'C;C++;Dart;Java;Kotlin;Python;SQL',
#  'C#;HTML/CSS;PowerShell;TypeScript',
#  'HTML/CSS;Java;JavaScript;Objective-C;PHP;Python;SQL;Swift;TypeScript',
#  'Assembly;Bash/Shell;C;C++;HTML/CSS;JavaScript;OCaml;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;C++;Go;Python;SQL',
#  'C#;C++;Dart;Java;JavaScript;Kotlin;PowerShell;Ruby;Rust;SQL;Swift;TypeScript',
#  'Bash/Shell;C;C++;Fortran;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;C;C++;Go;HTML/CSS;Java;JavaScript;Kotlin;Lua;Objective-C;Perl;PHP;PowerShell;Python;R;Ruby;Rust;SQL;Swift;TypeScript',
#  'Bash/Shell;C#;C++;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell;C++;HTML/CSS;JavaScript;Python;TypeScript',
#  'C++;Elixir;HTML/CSS;Java;JavaScript;OCaml;Python;TypeScript',
#  'Go;HTML/CSS;Java;JavaScript;PHP;SQL',
#  'C;Clojure;Crystal;Go;Java;Kotlin;LISP;Rust;SQL',
#  'C++;Lua;Python;TypeScript',
#  'Bash/Shell;C#;C++;HTML/CSS;Java;Kotlin;Objective-C;Python;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Perl;Python;Ruby;SQL',
#  'C#;HTML/CSS;PHP;PowerShell;SQL',
#  'HTML/CSS;JavaScript;Objective-C;Python;Swift',
#  'Bash/Shell;C;Python;Rust',
#  'Go;JavaScript;Python;R;SQL',
#  'Bash/Shell;C;C#;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;Java;Python;Rust',
#  'Bash/Shell;C;C++;Haskell;Java;Julia;Kotlin;LISP;OCaml;Perl;Ruby;Rust;Scala;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;Rust;SQL',
#  'Assembly;Bash/Shell;C;C#;Clojure;Erlang;Haskell;HTML/CSS;Java;JavaScript;Lua;PowerShell;Python;Rust;SQL',
#  'Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Python;SQL',
#  'Bash/Shell;C++;HTML/CSS;JavaScript;Objective-C;Python;Rust;SQL;Swift;TypeScript',
#  'Bash/Shell;JavaScript;Python;TypeScript',
#  'C++;Go;Java;Ruby;SQL',
#  'Go;Java;JavaScript;Kotlin;Objective-C;Swift;TypeScript',
#  'Objective-C;PHP;Swift',
#  'Bash/Shell;C;HTML/CSS;Java;JavaScript;Lua;PowerShell;Python;TypeScript',
#  'Bash/Shell;C++;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;C;C#;F#;Java;JavaScript;LISP;Objective-C;Ruby;Swift;TypeScript',
#  'Bash/Shell;C++;Go;HTML/CSS;Java;JavaScript;MATLAB;PowerShell;Python',
#  'JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell;C#;Dart;Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Rust;Solidity;SQL;Swift;TypeScript',
#  'Bash/Shell;HTML/CSS;Python;Rust;SQL',
#  'C#;Elixir;Go;Rust',
#  'Assembly;Bash/Shell;C;HTML/CSS;Python;Rust',
#  'C;HTML/CSS;JavaScript;Python;Ruby',
#  'JavaScript;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;Objective-C;PHP;Python;SQL;Swift;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Lua;Rust;SQL;TypeScript',
#  'Go;HTML/CSS;JavaScript;Objective-C;PHP;Ruby;Rust;SQL;Swift;TypeScript',
#  'C#;C++;PowerShell;Rust;TypeScript',
#  'C;C++;HTML/CSS;Java;JavaScript;Python;Rust',
#  'Bash/Shell;C;C#;C++;Go;HTML/CSS;Java;JavaScript;Objective-C;Python;Rust;TypeScript;VBA',
#  'C;C#;C++;JavaScript;Lua;Rust;TypeScript',
#  'C#;JavaScript;PHP;Python;SQL;TypeScript',
#  'C;MATLAB;Python;Rust',
#  'Assembly;Bash/Shell;C;C++;Go;Python;SQL',
#  'C++;Go;HTML/CSS;JavaScript;Lua;Python;Rust;SQL;Swift;TypeScript',
#  'Bash/Shell;C;C++;HTML/CSS;JavaScript;PowerShell;Python',
#  'Assembly;Bash/Shell;C;Go;HTML/CSS;Java;JavaScript;Lua;Perl;PowerShell;Python;Rust;Scala;SQL;TypeScript;VBA',
#  'C++;MATLAB;Python',
#  'Bash/Shell;Dart;HTML/CSS;JavaScript;Rust;SQL;Swift;TypeScript',
#  'Bash/Shell;C#;C++;Go;HTML/CSS;Java;JavaScript;Lua;Perl;PowerShell;Python;R;Rust;SQL;TypeScript',
#  'C;C++;JavaScript;Objective-C;Python',
#  'Go;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Go;HTML/CSS;JavaScript;SQL',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Julia;Python;R;Rust;SQL;TypeScript',
#  'C#;HTML/CSS;SQL;TypeScript',
#  'Bash/Shell;C++;Go;HTML/CSS;JavaScript;MATLAB;Python;Rust',
#  'Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Solidity;TypeScript',
#  'Assembly;Bash/Shell;C;C#;C++;HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;PHP;PowerShell;SQL;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;R',
#  'Bash/Shell;HTML/CSS;Lua;Python;TypeScript',
#  'Bash/Shell;HTML/CSS;JavaScript;SQL',
#  'Assembly;Bash/Shell;C;C#;C++;F#;HTML/CSS;Java;JavaScript;PowerShell;Python;Ruby;Rust;TypeScript',
#  'Assembly;Bash/Shell;C;Go;Java;JavaScript;Lua;Python;Solidity;TypeScript',
#  'Bash/Shell;C#;JavaScript;SQL;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;Java;JavaScript;Kotlin;MATLAB;Python;Swift',
#  'Bash/Shell;Haskell;Python;SQL',
#  'Bash/Shell;Clojure;HTML/CSS;Java;JavaScript;LISP;PHP;Python;SQL',
#  'HTML/CSS;TypeScript',
#  'Bash/Shell;C++;Groovy;Lua;Python;SQL',
#  'Java;JavaScript;Kotlin',
#  'Bash/Shell;Clojure;JavaScript;Julia;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;Go;Ruby;SQL',
#  'Assembly;C;C#;Dart;HTML/CSS;JavaScript;TypeScript',
#  'C;C++;Go;PHP;Python;Ruby',
#  'Bash/Shell;Crystal;Elixir;Go;HTML/CSS;Java;JavaScript;Kotlin;Lua;Objective-C;Ruby;Rust;Swift;TypeScript',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Dart;HTML/CSS;JavaScript;Lua;Objective-C',
#  'C;C++;Fortran;HTML/CSS',
#  'Bash/Shell;C;C++;Go;Java;JavaScript;LISP;Python;R;Ruby;SQL;TypeScript',
#  'C#;C++;Dart;HTML/CSS;Java;JavaScript;Kotlin;Python;SQL',
#  'Bash/Shell;HTML/CSS;Java;JavaScript',
#  'Bash/Shell;Java;Scala;SQL',
#  'Bash/Shell;C#;Java;JavaScript;PowerShell;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;C#;C++;Dart;Go;HTML/CSS;Java;JavaScript;MATLAB;Python;SQL',
#  'Bash/Shell;Go;Python;Scala',
#  'Assembly;Bash/Shell;C;C++;JavaScript;OCaml;Perl;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;Java;JavaScript;OCaml;PHP;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell;Rust;SQL',
#  'Bash/Shell;C;C++;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;Groovy;Java;JavaScript;SQL;TypeScript',
#  'Bash/Shell;Dart;Java;Python',
#  'Assembly;Bash/Shell;C;C#;C++;Delphi;Elixir;Erlang;Go;Groovy;HTML/CSS;Java;JavaScript;MATLAB;Objective-C;PHP;Python;Ruby;SQL;Swift;TypeScript',
#  'Bash/Shell;Clojure;Elixir;Erlang;Python;Ruby;Rust;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;C#;C++;LISP;Python;Rust;SQL',
#  'C;C++;Fortran;Python',
#  'Bash/Shell;C++;LISP;MATLAB;Python',
#  'Bash/Shell;C;C#;C++;Elixir;Erlang;Go;Haskell;JavaScript;Ruby;Rust;SQL;TypeScript',
#  'Bash/Shell;C;C++;HTML/CSS;JavaScript;Python;Rust;SQL',
#  'C;C#;C++;HTML/CSS;Java;Objective-C;Python;Swift',
#  'C#;HTML/CSS;JavaScript;PHP;TypeScript',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;Python;Ruby;TypeScript',
#  'C;C++;COBOL;Fortran;Java;Perl;PowerShell;Python;R;SAS;SQL;VBA',
#  'Groovy;SQL',
#  'Bash/Shell;C;C++;Go;HTML/CSS;JavaScript;PHP;Python;Ruby;Rust;SQL;TypeScript',
#  'Assembly;Bash/Shell;C;Go;Haskell;HTML/CSS;Java;JavaScript;Lua;Objective-C;Perl;PHP;Python;R;Ruby;Rust;SQL;TypeScript',
#  'C#;PowerShell;Python;SQL',
#  'Bash/Shell;C;C#;Go;Haskell;HTML/CSS;JavaScript;Perl;PHP;Python;Ruby;Rust',
#  'C++;Julia',
#  'C;C++;HTML/CSS;JavaScript;Lua;MATLAB;TypeScript',
#  'Assembly;Bash/Shell;C;C++;Go;HTML/CSS;Java;JavaScript;Perl;Python;Scala;SQL',
#  'HTML/CSS;JavaScript;Ruby;Swift',
#  'Bash/Shell;C;C++;Fortran;Java;Python;SQL',
#  'C;C++;Julia;Python',
#  'C;Clojure;HTML/CSS;Java;JavaScript;Python;Rust',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;Python;Ruby;SQL;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;PowerShell;SQL;TypeScript',
#  'Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;Python',
#  'Groovy;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'APL;Bash/Shell;C++;Clojure;HTML/CSS;JavaScript;OCaml;PHP;Python;Rust;TypeScript',
#  'C;C++;Go;JavaScript;Lua;Python;Rust;TypeScript',
#  'C++;Fortran;Java;JavaScript;Kotlin;MATLAB;Python;Swift',
#  'Bash/Shell;HTML/CSS;JavaScript;Python;TypeScript',
#  'Assembly;Bash/Shell;C;Fortran;Go;HTML/CSS;Java;JavaScript;LISP;Python;Rust;SQL;TypeScript',
#  'Bash/Shell;Groovy;HTML/CSS;JavaScript;Python;R;SAS;SQL',
#  'Bash/Shell;C#;HTML/CSS;JavaScript;Rust;SQL',
#  'Bash/Shell;C;C#;C++;Groovy;HTML/CSS;Java;JavaScript;Kotlin;PowerShell;Python;SQL;TypeScript',
#  'C;C#;C++;Python;R',
#  'Bash/Shell;C#;HTML/CSS;Java;JavaScript;Perl;PHP;PowerShell;Python;SQL;VBA',
#  'Bash/Shell;C#;C++;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell;C#;JavaScript;PowerShell;Rust;SQL;TypeScript',
#  'Groovy;HTML/CSS;JavaScript;TypeScript',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Perl;Ruby;SQL',
#  'C++;Python;SQL',
#  'Bash/Shell;Go;HTML/CSS;JavaScript;PHP;Scala;SQL',
#  'C++;Java;Python',
#  'JavaScript;Python;SQL',
#  'Bash/Shell;Dart;Java;JavaScript;SQL;TypeScript',
#  'Bash/Shell;JavaScript;Ruby;TypeScript',
#  'Bash/Shell;Perl;Python',
#  'Bash/Shell;Haskell;HTML/CSS;Java;JavaScript;Kotlin;LISP;PowerShell;Python;SQL;TypeScript',
#  'Go;HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell;C#;Delphi;HTML/CSS;JavaScript;PHP;PowerShell;SQL;TypeScript;VBA',
#  'Bash/Shell;C;C#;C++;HTML/CSS;JavaScript;Python;Swift;TypeScript',
#  'C#;Go;Java;Kotlin;Python;Ruby;SQL',
#  'Bash/Shell;HTML/CSS;JavaScript;Perl;PHP;PowerShell;Python;SQL',
#  'Bash/Shell;Groovy;Java;JavaScript;TypeScript',
#  'C++;JavaScript;LISP;PHP;Python;R;SQL;VBA',
#  'HTML/CSS;JavaScript;PHP',
#  'Julia;LISP;Python;R',
#  'C#;Clojure;F#;JavaScript;SQL',
#  'Bash/Shell;C;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL',
#  'Bash/Shell;HTML/CSS;R;SAS;SQL',
#  'Bash/Shell;Crystal;HTML/CSS;Java;LISP;Lua',
#  'Bash/Shell;HTML/CSS;Java;JavaScript;SQL',
#  'COBOL;Groovy;HTML/CSS;Java;JavaScript;Python;TypeScript',
#  'C#;HTML/CSS;JavaScript;PHP;Python;SQL',
#  'Bash/Shell;C#;JavaScript;PHP;Python;Rust;TypeScript',
#  'C;C++;Dart;HTML/CSS;Java;JavaScript;Lua;Python;R;SQL',
#  'Bash/Shell;C;HTML/CSS;Julia',
#  'Assembly;Bash/Shell;Haskell;HTML/CSS;JavaScript;Lua;Python;Rust',
#  'Clojure;Java;JavaScript;LISP;Python;R;SQL',
#  'Bash/Shell;Clojure;JavaScript;Python;Rust;TypeScript',
#  'C;C++;Groovy;Java;JavaScript;Kotlin;Python;Rust',
#  ...]

# %%
df2022_USpro.LanguageWantToWorkWith.unique()
# Out:
# array(['C#;Elixir;F#;Go;JavaScript;Rust;TypeScript',
#        'Haskell;HTML/CSS;Rust;Swift', 'HTML/CSS;JavaScript;Python;Scala',
#        ..., 'Bash/Shell;HTML/CSS;JavaScript;PowerShell;Python;TypeScript',
#        'Bash/Shell;C++;HTML/CSS;JavaScript;Perl;Python;Rust;TypeScript',
#        'C#;Java;Kotlin;Python;Scala;SQL;TypeScript'], dtype=object)

# %%
df2022_USpro.LearnCodeCoursesCert.unique()
# Out:
# array([nan, 'Pluralsight', 'Codecademy', 'Udemy;Codecademy;Pluralsight',
#        'Udemy;Codecademy', 'Other', 'Codecademy;Pluralsight',
#        'Coursera;Pluralsight', 'Codecademy;Other', 'Coursera;Udacity',
#        'Udemy', 'Coursera;Other', 'Coursera;Codecademy;edX;Other',
#        'Codecademy;Skillsoft', 'Coursera;edX',
#        'Udemy;Codecademy;Pluralsight;Other', 'Udemy;Pluralsight;Other',
#        'Codecademy;Pluralsight;Other', 'Udemy;Codecademy;Other',
#        'Udemy;Pluralsight', 'Udemy;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity',
#        'Coursera;Udemy', 'Coursera;Udemy;Codecademy', 'Coursera',
#        'Coursera;Udemy;Pluralsight;edX',
#        'Udemy;Codecademy;Pluralsight;Skillsoft', 'Pluralsight;edX',
#        'Coursera;Udemy;Pluralsight;Other',
#        'Coursera;Udemy;Codecademy;edX',
#        'Udemy;Codecademy;Pluralsight;Udacity', 'Coursera;Codecademy',
#        'Coursera;Udemy;edX;Other', 'Coursera;Pluralsight;edX',
#        'Coursera;Codecademy;Udacity', 'Codecademy;Pluralsight;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;edX;Other',
#        'Coursera;Udemy;Udacity', 'Coursera;Udemy;edX;Udacity',
#        'Udemy;Udacity', 'Pluralsight;Other', 'Skillsoft',
#        'Udemy;Pluralsight;Skillsoft',
#        'Coursera;Udemy;Codecademy;edX;Udacity',
#        'Udemy;Codecademy;Udacity;Other', 'Udemy;edX', 'Udacity',
#        'Coursera;Udemy;Pluralsight', 'Coursera;Udemy;Codecademy;Udacity',
#        'Coursera;Udemy;edX', 'Udemy;Other', 'Coursera;Skillsoft',
#        'Udemy;Codecademy;edX;Other', 'Coursera;Codecademy;Other',
#        'Coursera;edX;Udacity', 'Coursera;Udemy;Pluralsight;Udacity',
#        'Udemy;Pluralsight;Udacity', 'Coursera;Codecademy;edX;Udacity',
#        'Codecademy;edX;Udacity', 'Udemy;Codecademy;Pluralsight;edX',
#        'Codecademy;edX;Other', 'edX', 'Coursera;Codecademy;edX',
#        'Codecademy;edX', 'Coursera;Udemy;Pluralsight;edX;Udacity',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX',
#        'Udemy;Codecademy;edX',
#        'Coursera;Codecademy;Pluralsight;edX;Udacity;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight',
#        'Coursera;Udemy;Pluralsight;Other;Skillsoft', 'Udemy;edX;Other',
#        'Codecademy;Pluralsight;edX', 'Coursera;Udacity;Other',
#        'Coursera;Udemy;Other', 'Udemy;Pluralsight;Udacity;Other',
#        'Coursera;Codecademy;Pluralsight;Other',
#        'Udemy;Codecademy;Udacity', 'Coursera;Udemy;Codecademy;edX;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity;Other',
#        'Udacity;Other', 'Udemy;Codecademy;Pluralsight;edX;Udacity',
#        'Pluralsight;Udacity', 'Udemy;Pluralsight;edX',
#        'Coursera;Udemy;edX;Skillsoft', 'Coursera;Codecademy;Pluralsight',
#        'Coursera;Udemy;Codecademy;edX;Skillsoft',
#        'Codecademy;Pluralsight;Udacity',
#        'Udemy;Codecademy;Pluralsight;Udacity;Other',
#        'Coursera;Codecademy;Pluralsight;edX',
#        'Coursera;Pluralsight;edX;Udacity',
#        'Coursera;Codecademy;Pluralsight;Udacity',
#        'Codecademy;Pluralsight;edX;Other', 'Coursera;edX;Udacity;Other',
#        'Coursera;Udemy;Codecademy;Other', 'Udemy;Codecademy;Skillsoft',
#        'Codecademy;Udacity',
#        'Coursera;Udemy;Pluralsight;Udacity;Skillsoft',
#        'Coursera;Pluralsight;Udacity;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Other',
#        'Pluralsight;Skillsoft',
#        'Coursera;Udemy;Codecademy;edX;Udacity;Other',
#        'Codecademy;Udacity;Other',
#        'Coursera;Pluralsight;edX;Udacity;Skillsoft', 'edX;Other',
#        'Coursera;Udemy;Codecademy;Udacity;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;Udacity;Other;Skillsoft',
#        'Udemy;Codecademy;edX;Udacity',
#        'Udemy;Codecademy;Pluralsight;Other;Skillsoft',
#        'Coursera;Udemy;Udacity;Other', 'Udemy;Udacity;Other',
#        'Coursera;edX;Other', 'Coursera;Pluralsight;Other',
#        'Coursera;Pluralsight;edX;Other',
#        'Coursera;Codecademy;Pluralsight;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;Udacity;Skillsoft',
#        'Coursera;Udemy;Pluralsight;edX;Udacity;Skillsoft',
#        'Udemy;edX;Udacity', 'Coursera;Udemy;Skillsoft',
#        'Coursera;Udemy;Pluralsight;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;Udacity;Other',
#        'Udemy;Other;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity;Other;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity;Skillsoft',
#        'Coursera;Udemy;Codecademy;edX;Udacity;Skillsoft',
#        'Coursera;Pluralsight;edX;Skillsoft',
#        'Coursera;Pluralsight;Udacity', 'Udemy;Pluralsight;edX;Other',
#        'Coursera;Pluralsight;Skillsoft', 'Udemy;Pluralsight;edX;Udacity',
#        'Codecademy;Pluralsight;edX;Udacity;Other',
#        'Coursera;Udemy;Pluralsight;edX;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight;Udacity',
#        'Pluralsight;Other;Skillsoft',
#        'Udemy;Pluralsight;edX;Udacity;Other',
#        'Coursera;Udemy;Pluralsight;Udacity;Other',
#        'Coursera;Codecademy;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight;Other;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;Skillsoft',
#        'Other;Skillsoft', 'Coursera;Udemy;Pluralsight;edX;Udacity;Other',
#        'edX;Udacity;Other', 'edX;Udacity',
#        'Coursera;Udemy;Codecademy;Skillsoft',
#        'Coursera;Udemy;Other;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;Udacity;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;edX;Other',
#        'Udemy;edX;Udacity;Other',
#        'Coursera;Codecademy;Pluralsight;edX;Udacity',
#        'Codecademy;Pluralsight;Udacity;Other', 'Udemy;Udacity;Skillsoft',
#        'Udemy;Codecademy;Udacity;Skillsoft',
#        'Coursera;Udemy;Pluralsight;edX;Skillsoft',
#        'Coursera;Udemy;Codecademy;Udacity;Other',
#        'Coursera;Pluralsight;Other;Skillsoft'], dtype=object)

# %% [markdown]
# These features have the same challenge as platform features, so I have to use explode() to separate the values and get counts for each language. The plan: separate devtype into new rows, then subset by devtypes, then explode each language column to make counts per dev type.

# %%
df2022_USpro_explode_devtype = df2022_USpro.assign(devtype=df2022_USpro.DevType.str.split(';')).explode('devtype').reset_index(drop=True)

# %%
df2022_USpro_explode_devtype.head(3)
# Out:
#                        MainBranch           Employment  \
# 0  I am a developer by profession  Employed, full-time
# 1  I am a developer by profession  Employed, full-time
# 2  I am a developer by profession  Employed, full-time
#
#                              RemoteWork CodingActivities  \
# 0  Hybrid (some remote, some in-person)            Hobby
# 1  Hybrid (some remote, some in-person)            Hobby
# 2  Hybrid (some remote, some in-person)            Hobby
#
#                                         EdLevel  \
# 0  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0  Other online resources (e.g., videos, blogs, f...
# 1  Other online resources (e.g., videos, blogs, f...
# 2  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0  Technical documentation;Blogs;Stack Overflow;O...                  NaN
# 1  Technical documentation;Blogs;Stack Overflow;O...                  NaN
# 2  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode YearsCodePro  ... TimeAnswering Onboarding ProfessionalTech  \
# 0         8            3  ...           NaN        NaN              NaN
# 1         8            3  ...           NaN        NaN              NaN
# 2         8            3  ...           NaN        NaN              NaN
#
#   TrueFalse_1 TrueFalse_2 TrueFalse_3 SurveyLength SurveyEase  \
# 0         NaN         NaN         NaN     Too long       Easy
# 1         NaN         NaN         NaN     Too long       Easy
# 2         NaN         NaN         NaN     Too long       Easy
#
#   ConvertedCompYearly                devtype
# 0                 NaN   Developer, front-end
# 1                 NaN  Developer, full-stack
# 2                 NaN    Developer, back-end
#
# [3 rows x 77 columns]

# %%
#checking that each dev type was separated
df2022_USpro_explode_devtype.devtype.unique().tolist()
# Out:
# ['Developer, front-end',
#  'Developer, full-stack',
#  'Developer, back-end',
#  'Developer, desktop or enterprise applications',
#  'Developer, QA or test',
#  'Academic researcher',
#  'DevOps specialist',
#  'Developer, embedded applications or devices',
#  'Developer, game or graphics',
#  'Engineer, data',
#  'Developer, mobile',
#  'Database administrator',
#  'Cloud infrastructure engineer',
#  'Data or business analyst',
#  'Designer',
#  'Marketing or sales professional',
#  'Data scientist or machine learning specialist',
#  'Security professional',
#  'Project manager',
#  'Senior Executive (C-Suite, VP, etc.)',
#  'Engineering manager',
#  'System administrator',
#  'Student',
#  'Other (please specify):',
#  'Scientist',
#  nan,
#  'Product manager',
#  'Engineer, site reliability',
#  'Educator',
#  'Blockchain']

# %%
I am interested in the Data scientist or machine learning specialist Dev type so lets subset by this dev type!

# %%
df2022_USpro_DS=df2022_USpro_explode_devtype[df2022_USpro_explode_devtype['devtype']=='Data scientist or machine learning specialist']
df2022_USpro_DS.shape
# Out:
# (532, 77)

# %% [markdown]
# Now from this subset of 532 data scientists, let look at the languages they are using and the ones they want to learn about.

# %%
df2022_USpro_DS_explode_currentlanguage = df2022_USpro_DS.assign(language=df2022_USpro_DS.LanguageHaveWorkedWith.str.split(';')).explode('language').reset_index(drop=True)
df2022_USpro_DS_explode_currentlanguage['language'].value_counts().sort_values().plot(kind='barh', color='grey',width=0.8)
# Out:
# <AxesSubplot:>

# %%
df2022_USpro_DS_explode_wantlanguage = df2022_USpro_DS.assign(language=df2022_USpro_DS.LanguageWantToWorkWith.str.split(';')).explode('language').reset_index(drop=True)
df2022_USpro_DS_explode_wantlanguage['language'].value_counts().sort_values().plot(kind='barh', color='purple',width=0.8)
# Out:
# <AxesSubplot:>

# %%
ratio=(df2022_USpro_DS_explode_wantlanguage['language'].value_counts()/df2022_USpro_DS_explode_currentlanguage['language'].value_counts())-1

# %%
ratio.sort_values().plot(kind='barh', color='violet',width=0.8, title='Data Scientists and Machine Learning specialists wanted to learn these languages in 2022')
# Out:
# <AxesSubplot:title={'center':'Data Scientists and Machine Learning specialists wanted to learn these languages in 2022'}>

# %%
I am also curious to know the languages data scientists want to learn by year of coding professionally. I am going to make age of coding experience plots by languages

# %%
df2022_USpro_DS['YearsCodePro'].value_counts().plot(kind='barh', title='Distribution of years of coding experience in Data Scientists')
# Out:
# <AxesSubplot:title={'center':'Distribution of years of coding experience in Data Scientists'}>

# %% [markdown]
# The majority of survey participants who are data scientists and machine learning specialists have between 1 and 10 years of experience

# %%
df2022_USpro_DS_explode_wantlanguage.head(3)
# Out:
#                        MainBranch           Employment  \
# 0  I am a developer by profession  Employed, full-time
# 1  I am a developer by profession  Employed, full-time
# 2  I am a developer by profession  Employed, full-time
#
#                              RemoteWork CodingActivities  \
# 0  Hybrid (some remote, some in-person)            Hobby
# 1  Hybrid (some remote, some in-person)            Hobby
# 2  Hybrid (some remote, some in-person)            Hobby
#
#                                         EdLevel  \
# 0  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0  Books / Physical media;Other online resources ...
# 1  Books / Physical media;Other online resources ...
# 2  Books / Physical media;Other online resources ...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0  Technical documentation;Blogs;Written Tutorial...                  NaN
# 1  Technical documentation;Blogs;Written Tutorial...                  NaN
# 2  Technical documentation;Blogs;Written Tutorial...                  NaN
#
#   YearsCode YearsCodePro  ...      Onboarding  \
# 0        10            7  ...  Somewhat short
# 1        10            7  ...  Somewhat short
# 2        10            7  ...  Somewhat short
#
#                                     ProfessionalTech TrueFalse_1 TrueFalse_2  \
# 0  Developer portal or other central places to fi...          No          No
# 1  Developer portal or other central places to fi...          No          No
# 2  Developer portal or other central places to fi...          No          No
#
#   TrueFalse_3           SurveyLength SurveyEase ConvertedCompYearly  \
# 0         Yes  Appropriate in length       Easy             95000.0
# 1         Yes  Appropriate in length       Easy             95000.0
# 2         Yes  Appropriate in length       Easy             95000.0
#
#                                          devtype language
# 0  Data scientist or machine learning specialist  Clojure
# 1  Data scientist or machine learning specialist     Dart
# 2  Data scientist or machine learning specialist       Go
#
# [3 rows x 78 columns]

# %%
df2022_USpro_DS_explode_wantlanguage[df2022_USpro_DS_explode_wantlanguage['language']=='Julia']['YearsCodePro'].value_counts().plot(kind='barh')

# %%
#subset by the 3 top languages
ratio=df2022_USpro_DS_explode_wantlanguage['language'].value_counts()/df2022_USpro_DS_explode_currentlanguage['language'].value_counts()

ratio.sort_values(ascending=False)
# Out:
# Rust           2.581081
# Julia          2.177778
# F#             2.166667
# Haskell        2.050000
# Elixir         1.769231
# OCaml          1.692308
# Clojure        1.578947
# Go             1.363636
# Erlang         1.363636
# Swift          1.354839
# LISP           1.214286
# Solidity       1.142857
# Crystal        1.125000
# Dart           1.083333
# Scala          1.000000
# APL            1.000000
# Delphi         1.000000
# Kotlin         0.947368
# Lua            0.903226
# TypeScript     0.891667
# Ruby           0.818182
# Python         0.801325
# R              0.720280
# C++            0.690789
# Groovy         0.681818
# SQL            0.659639
# Objective-C    0.625000
# C#             0.623762
# Bash/Shell     0.582418
# JavaScript     0.579151
# Assembly       0.567568
# C              0.555556
# HTML/CSS       0.519048
# Perl           0.512821
# PowerShell     0.458824
# Fortran        0.458333
# COBOL          0.444444
# Java           0.429630
# PHP            0.384615
# SAS            0.370370
# MATLAB         0.333333
# VBA            0.333333
# Name: language, dtype: float64

# %%
top=['Rust','Julia','F#','Haskell']
top_languages=df2022_USpro_DS_explode_wantlanguage[df2022_USpro_DS_explode_wantlanguage['language'].isin(top)]

# %%
sns.displot(
    top_languages, x="YearsCodePro", col="language", 
    binwidth=3, height=10, facet_kws=dict()
)
#NB: this visual can be improved by reorder the years of experience

# %% [markdown]
# Conclusion: starting from 2 years of experience coding professionally, data scientist and machine learning specialists in the US want to learn other languages such as Rust and Julia

# %% [markdown]
# Since I am starting in data science and want to find a job, I want to see what languages people with one year or less coding professionally are using and what they want to learn

# %%
# subsetting less than one year experience participants
one=['Less than 1 year','1']
DS_one=df2022_USpro_DS[df2022_USpro_DS['YearsCodePro'].isin(one)]
DS_one.shape
# Out:
# (35, 77)

# %%
#lets explode() our languages columns and make plots
DS_one_explode_currentlanguage = DS_one.assign(language=DS_less.LanguageHaveWorkedWith.str.split(';')).explode('language').reset_index(drop=True)
# Out:
# (210, 78)

# %%
DS_one_explode_currentlanguage['language'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Python and SQL are the most used languages then C++ and Bash/Shell

# %%
DS_one_explode_wantlanguage = DS_one.assign(language=DS_less.LanguageWantToWorkWith.str.split(';')).explode('language').reset_index(drop=True)
# Out:
# (165, 78)

# %%
DS_one_explode_wantlanguage['language'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
ratio_one=(DS_one_explode_wantlanguage['language'].value_counts()/DS_one_explode_currentlanguage['language'].value_counts())-1
ratio_one.sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Conclusion: Rust and scala are the two top languages that need to be watched as an early career data scientist in the US.

# %% [markdown]
# # Question 3: What are the most popular learning platforms among data scientists
#
# Sub question, are students and professionals used/ are using the same learning platforms to learn data science and coding?

# %%
# let's explore certifications among data scientists
df2022_US.MainBranch.value_counts()
# Out:
# I am a developer by profession                                                   10288
# I am not primarily a developer, but I write code sometimes as part of my work     1256
# I code primarily as a hobby                                                       1060
# I am learning to code                                                              673
# I used to be a developer by profession, but no longer am                           266
# Name: MainBranch, dtype: int64

# %%
df2022_US.LearnCodeCoursesCert
# Out:
# 4                                     NaN
# 11                                    NaN
# 12                                    NaN
# 14                                    NaN
# 26                                    NaN
#                        ...
# 73231                                 NaN
# 73240                                 NaN
# 73254       Coursera;Udemy;Codecademy;edX
# 73264              Coursera;Udemy;Udacity
# 73265    Udemy;Codecademy;Pluralsight;edX
# Name: LearnCodeCoursesCert, Length: 13543, dtype: object

# %%
# subsetting df2022_US by devtype to filter data scientists
df2022_US.DevType.unique()
# Out:
# array(['Developer, front-end;Developer, full-stack;Developer, back-end;Developer, desktop or enterprise applications;Developer, QA or test',
#        'Engineering manager', 'Developer, full-stack', ...,
#        'Developer, front-end;Engineer, data;Engineer, site reliability;Developer, full-stack;Developer, back-end;Developer, QA or test;Developer, mobile;Engineering manager;Database administrator;Cloud infrastructure engineer;Data or business analyst;Designer;System administrator;Security professional',
#        'Data scientist or machine learning specialist;Developer, back-end;Project manager;Data or business analyst',
#        'Data scientist or machine learning specialist;Data or business analyst;Product manager'],
#       dtype=object)

# %%
df2022_US_explode_devtype = df2022_US.assign(devtype=df2022_US.DevType.str.split(';')).explode('devtype').reset_index(drop=True)

# %%
df2022_US_explode_devtype.devtype.value_counts()
# Out:
# Developer, full-stack                            5697
# Developer, back-end                              4760
# Developer, front-end                             2627
# Developer, desktop or enterprise applications    1797
# Cloud infrastructure engineer                    1299
# DevOps specialist                                1296
# System administrator                             1067
# Database administrator                           1050
# Developer, mobile                                1047
# Engineering manager                              1012
# Engineer, data                                    853
# Designer                                          789
# Developer, embedded applications or devices       782
# Data or business analyst                          707
# Other (please specify):                           701
# Student                                           700
# Data scientist or machine learning specialist     685
# Developer, QA or test                             682
# Project manager                                   648
# Engineer, site reliability                        556
# Security professional                             524
# Senior Executive (C-Suite, VP, etc.)              517
# Product manager                                   486
# Academic researcher                               482
# Scientist                                         422
# Educator                                          361
# Developer, game or graphics                       339
# Blockchain                                        203
# Marketing or sales professional                   150
# Name: devtype, dtype: int64

# %%
df2022_US_DSall=df2022_US_explode_devtype[df2022_US_explode_devtype['devtype']=='Data scientist or machine learning specialist']

# %%
#separate ech learning platform
df2022_US_DSall_explode_certif = df2022_US_DSall.assign(certif=df2022_US_DSall.LearnCodeCoursesCert.str.split(';')).explode('certif').reset_index(drop=True)

# %%
df2022_US_DSall_explode_certif.groupby('MainBranch').certif.value_counts().unstack(0).plot(kind='barh')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
df_data.LearnCodeCoursesCert.unique()
# Out:
# array([nan, 'Codecademy;Pluralsight', 'Udemy', 'Codecademy;Skillsoft',
#        'Coursera;Udemy', 'Coursera;Pluralsight;edX',
#        'Coursera;Pluralsight', 'Other', 'Codecademy;edX;Udacity',
#        'Coursera', 'Coursera;Udemy;Codecademy', 'Coursera;Other',
#        'Coursera;Udemy;Codecademy;edX;Udacity', 'Coursera;edX',
#        'Udemy;Pluralsight', 'Coursera;Udacity',
#        'Coursera;Codecademy;edX;Udacity', 'Coursera;Udemy;edX;Other',
#        'Pluralsight;Udacity', 'Coursera;Udemy;Udacity',
#        'Coursera;Udemy;Codecademy;edX', 'Coursera;edX;Udacity;Other',
#        'Coursera;Udemy;Pluralsight;Udacity;Skillsoft',
#        'Udemy;Pluralsight;Udacity', 'Codecademy;Other',
#        'Pluralsight;Other', 'Coursera;Udemy;edX;Udacity',
#        'Coursera;Codecademy;Pluralsight', 'Udemy;Skillsoft',
#        'Coursera;Udemy;Other', 'Codecademy', 'Coursera;Codecademy', 'edX',
#        'Coursera;Udemy;Pluralsight;Udacity',
#        'Coursera;Codecademy;Udacity', 'Coursera;Udemy;Pluralsight;edX',
#        'Coursera;Udemy;Udacity;Other',
#        'Udemy;Codecademy;Pluralsight;Udacity',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity;Other;Skillsoft',
#        'Udemy;Pluralsight;edX', 'Coursera;Pluralsight;Skillsoft',
#        'Udemy;Codecademy;Other', 'Coursera;Udemy;Codecademy;Udacity',
#        'Udemy;Pluralsight;Other',
#        'Coursera;Udemy;Codecademy;edX;Udacity;Other', 'Pluralsight',
#        'Pluralsight;edX', 'Coursera;Udemy;Pluralsight;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight', 'Udemy;Codecademy',
#        'Udemy;Codecademy;Pluralsight;Other;Skillsoft',
#        'Coursera;edX;Other', 'Coursera;edX;Udacity',
#        'Udemy;Codecademy;Pluralsight', 'Coursera;Udemy;edX',
#        'Other;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity',
#        'Udemy;edX;Other', 'Coursera;Udemy;Pluralsight', 'Udemy;Udacity',
#        'Udacity', 'Pluralsight;Skillsoft', 'Coursera;Skillsoft',
#        'Coursera;Pluralsight;edX;Skillsoft', 'Udemy;edX', 'Udemy;Other',
#        'Coursera;Pluralsight;edX;Udacity',
#        'Coursera;Codecademy;Pluralsight;edX;Other',
#        'Coursera;Udemy;Pluralsight;edX;Other'], dtype=object)

# %%
data_folks=['Data scientist or machine learning specialist']

df_data=df2022_USpro_explode_devtype[df2022_USpro_explode_devtype['devtype'].isin(data_folks)]
df_data.shape
# Out:
# (532, 77)

# %% [markdown]
# I made the decision to work with only participants that identified themselves having a data scientist role. there are in toal 532 survey participants in the US.

# %%
# Out:
# 157

# %%
sns.boxplot(x='ConvertedCompYearly',
            data=df_data_drop[df_data_drop['ConvertedCompYearly']<=0.1e7])
plt.ticklabel_format(style='plain', axis='x')
# in the plot, I have removed outliers arbitrarily for salary above UAS1M

# %% [markdown]
# To better visualize salary, I arbitraily removed compensation above USD 1M, even so, the distribution is quite skewed towards the left because of few very high yearly compensation

# %%
np.log10(df_data_drop['ConvertedCompYearly']).hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Log transformation of the compensation column allows us to have a more normally distributed curve, so I will check if this can be done in my model directly, or I will transform my target column before fitting the model.
#
# Next on, I will select my features.

# %% [markdown]
# ### Features
# For the sake of running a simple model, even though I know that other features unrelated to demographic of the survey may help obtain a better model, I will stick to selecting and engineering demographic features for this first exercice. Let's how the model performs.

# %%
df_data_drop.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'Blockchain', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity',
#        'Accessibility', 'MentalHealth', 'TBranch', 'ICorPM', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Frequency_1',
#        'Frequency_2', 'Frequency_3', 'TimeSearching', 'TimeAnswering',
#        'Onboarding', 'ProfessionalTech', 'TrueFalse_1', 'TrueFalse_2',
#        'TrueFalse_3', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly',
#        'devtype', 'log_ConvertedCompYearly', 'ConvertedCompYearly_log10'],
#       dtype='object')

# %%
demographics=['ConvertedCompYearly','ConvertedCompYearly_log10','Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity','Accessibility', 'MentalHealth']

# %%
df_demog=df_data_drop[demographics]
df_demog.head()
# Out:
#      ConvertedCompYearly  ConvertedCompYearly_log10              Age Gender  \
# 40               95000.0                   4.977724  25-34 years old    Man
# 55               35000.0                   4.544068  25-34 years old    Man
# 68             6000000.0                   6.778151  45-54 years old    Man
# 117              75000.0                   4.875061  18-24 years old    Man
# 176             150000.0                   5.176091  25-34 years old    Man
#
#     Trans                Sexuality          Ethnicity      Accessibility  \
# 40     No  Straight / Heterosexual              White  None of the above
# 55     No  Straight / Heterosexual              White  None of the above
# 68     No  Straight / Heterosexual  Prefer not to say  None of the above
# 117    No  Straight / Heterosexual              White  None of the above
# 176    No  Straight / Heterosexual              White  None of the above
#
#                                           MentalHealth
# 40                                   Prefer not to say
# 55   I have an anxiety disorder;I have a concentrat...
# 68                                   None of the above
# 117                                  None of the above
# 176                         I have an anxiety disorder

# %%
I will first look at missing data in the feature columns, I have already removed rows without target data.

# %%
df_demog.isnull().sum()
# Out:
# ConvertedCompYearly           0
# ConvertedCompYearly_log10     0
# Age                           0
# Gender                        0
# Trans                         0
# Sexuality                     9
# Ethnicity                     5
# Accessibility                10
# MentalHealth                 15
# dtype: int64

# %%
df_demog['Accessibility'].unique().tolist()
# Out:
# ['None of the above',
#  nan,
#  'I am deaf / hard of hearing',
#  'Or, in your own words:',
#  'Prefer not to say',
#  'I am unable to / find it difficult to walk or stand without assistance',
#  'I am blind / have difficulty seeing']

# %%
df_demog['Accessibility'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df_demog['Ethnicity'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df_demog['Ethnicity'].apply(lambda x: len(str(x).split(';'))).value_counts()
# Out:
# 1    287
# 2     53
# 3     26
# 4      7
# 8      1
# 6      1
# Name: Ethnicity, dtype: int64

# %%
sns.pairplot(df_demog, hue='Ethnicity')

# %%
df_dropna_target = df2022.dropna(subset=['ConvertedCompYearly'],axis=0)

# %%
df_dropna_target['Currency'].unique()
#I will only use US currency
# Out:
# array(['GBP\tPound sterling', 'ILS\tIsraeli new shekel',
#        'EUR European Euro', 'USD\tUnited States dollar',
#        'CZK\tCzech koruna', 'CAD\tCanadian dollar', 'PLN\tPolish zloty',
#        'NOK\tNorwegian krone', 'TWD\tNew Taiwan dollar',
#        'BRL\tBrazilian real', 'UYU\tUruguayan peso', 'SEK\tSwedish krona',
#        'TRY\tTurkish lira', 'RON\tRomanian leu', 'SGD\tSingapore dollar',
#        'INR\tIndian rupee', 'BGN\tBulgarian lev', 'RUB\tRussian ruble',
#        'SAR\tSaudi Arabian riyal', 'KES\tKenyan shilling',
#        'CHF\tSwiss franc', 'ZAR\tSouth African rand', 'THB\tThai baht',
#        'CNY\tChinese Yuan Renminbi', 'DKK\tDanish krone',
#        'AUD\tAustralian dollar', 'VND\tVietnamese dong',
#        'ARS\tArgentine peso', 'HUF\tHungarian forint',
#        'TND\tTunisian dinar', 'BDT\tBangladeshi taka',
#        'MVR\tMaldivian rufiyaa', 'HKD\tHong Kong dollar',
#        'MXN\tMexican peso', 'EGP\tEgyptian pound', 'RSD\tSerbian dinar',
#        'PKR\tPakistani rupee', 'NPR\tNepalese rupee',
#        'HRK\tCroatian kuna', 'IDR\tIndonesian rupiah',
#        'BAM\tBosnia and Herzegovina convertible mark', 'IMP\tManx pound',
#        'IRR\tIranian rial', 'CRC\tCosta Rican colon',
#        'MUR\tMauritian rupee', 'KZT\tKazakhstani tenge',
#        'MAD\tMoroccan dirham', 'PHP\tPhilippine peso',
#        'NZD\tNew Zealand dollar', 'JPY\tJapanese yen',
#        'PEN\tPeruvian sol', 'UAH\tUkrainian hryvnia',
#        'COP\tColombian peso', 'GIP\tGibraltar pound',
#        'AED United Arab Emirates dirham', 'KRW\tSouth Korean won',
#        'LBP\tLebanese pound', 'MYR\tMalaysian ringgit',
#        'GTQ\tGuatemalan quetzal', 'AZN\tAzerbaijan manat',
#        'CLP\tChilean peso', 'LKR\tSri Lankan rupee',
#        'BYN\tBelarusian ruble', 'QAR\tQatari riyal',
#        'NGN\tNigerian naira', 'UZS\tUzbekistani som',
#        'AMD\tArmenian dram', 'ETB\tEthiopian birr',
#        'JOD\tJordanian dinar', 'FJD\tFijian dollar',
#        'MNT\tMongolian tugrik', 'TJS\tTajikistani somoni',
#        'GHS\tGhanaian cedi', 'AFN\tAfghan afghani',
#        'MKD\tMacedonian denar', 'TZS\tTanzanian shilling',
#        'DZD\tAlgerian dinar', 'MDL\tMoldovan leu',
#        'XAF\tCentral African CFA franc', 'TMT\tTurkmen manat',
#        'BWP\tBotswana pula', 'ALL\tAlbanian lek', 'MMK\tMyanmar kyat',
#        'MGA\tMalagasy ariary', 'GEL\tGeorgian lari',
#        'XOF\tWest African CFA franc', 'DOP\tDominican peso',
#        'RWF\tRwandan franc', 'KWD\tKuwaiti dinar',
#        'KYD\tCayman Islands dollar', 'HNL\tHonduran lempira',
#        'ISK\tIcelandic krona', 'BHD\tBahraini dinar',
#        'BOB\tBolivian boliviano', 'PYG\tParaguayan guarani',
#        'CUP\tCuban peso', 'UGX\tUgandan shilling',
#        'BBD\tBarbadian dollar', 'NIO\tNicaraguan cordoba',
#        'KGS\tKyrgyzstani som', 'IQD\tIraqi dinar', 'LAK\tLao kip',
#        'LYD\tLibyan dinar', 'MZN\tMozambican metical',
#        'AOA\tAngolan kwanza', 'AWG\tAruban florin', 'OMR\tOmani rial',
#        'SYP\tSyrian pound', 'SDG\tSudanese pound', 'ZMW Zambian kwacha',
#        'DJF\tDjiboutian franc', 'GNF\tGuinean franc',
#        'VES\tVenezuelan bolivar', 'TTD\tTrinidad and Tobago dollar',
#        'BTN\tBhutanese ngultrum', 'BMD\tBermudian dollar',
#        'JMD\tJamaican dollar', 'HTG\tHaitian gourde', 'YER\tYemeni rial',
#        'MWK\tMalawian kwacha', 'GYD\tGuyanese dollar', 'XPF\tCFP franc',
#        'XCD\tEast Caribbean dollar', 'SCR\tSeychellois rupee'],
#       dtype=object)

# %%
df_dropna_targetUS=df_dropna_target[df_dropna_target['Currency']=='USD\tUnited States dollar']

# %%
df_dropna_targetUS.head()
# Out:
#     ResponseId                                         MainBranch  \
# 11          12  I am not primarily a developer, but I write co...
# 12          13                     I am a developer by profession
# 14          15                     I am a developer by profession
# 26          27                     I am a developer by profession
# 28          29                     I am a developer by profession
#
#                                            Employment  \
# 11  Employed, full-time;Independent contractor, fr...
# 12                                Employed, full-time
# 14  Employed, full-time;Independent contractor, fr...
# 26                                Employed, full-time
# 28                                Employed, full-time
#
#                               RemoteWork  \
# 11                          Fully remote
# 12  Hybrid (some remote, some in-person)
# 14                          Fully remote
# 26  Hybrid (some remote, some in-person)
# 28  Hybrid (some remote, some in-person)
#
#                                      CodingActivities  \
# 11  Hobby;Contribute to open-source projects;Freel...
# 12                                              Hobby
# 14                      Hobby;Freelance/contract work
# 26                       I don’t code outside of work
# 28           Hobby;Contribute to open-source projects
#
#                                             EdLevel  \
# 11     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 14  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 26     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                             LearnCode  \
# 11  Other online resources (e.g., videos, blogs, f...
# 12            School (i.e., University, College, etc)
# 14  Other online resources (e.g., videos, blogs, f...
# 26  Books / Physical media;Other online resources ...
# 28  Books / Physical media;School (i.e., Universit...
#
#                                       LearnCodeOnline LearnCodeCoursesCert  \
# 11  Technical documentation;Blogs;Written Tutorial...                  NaN
# 12                                                NaN                  NaN
# 14  Written Tutorials;Stack Overflow;Video-based O...                  NaN
# 26  Technical documentation;Stack Overflow;Online ...                  NaN
# 28                                                NaN                  NaN
#
#    YearsCode  ...        TimeSearching               TimeAnswering  \
# 11        12  ...  30-60 minutes a day        60-120 minutes a day
# 12        12  ...  30-60 minutes a day  Less than 15 minutes a day
# 14        11  ...  30-60 minutes a day         30-60 minutes a day
# 26        10  ...                  NaN                         NaN
# 28        20  ...  30-60 minutes a day         15-30 minutes a day
#
#         Onboarding                                   ProfessionalTech  \
# 11      Just right  Innersource initiative;DevOps function;Microse...
# 12  Somewhat short                      DevOps function;Microservices
# 14   Somewhat long  DevOps function;Continuous integration (CI) an...
# 26             NaN                                                NaN
# 28   Somewhat long  Developer portal or other central places to fi...
#
#    TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength SurveyEase  \
# 11         Yes         Yes          No              Too short       Easy
# 12         Yes          No         Yes  Appropriate in length       Easy
# 14          No         Yes         Yes  Appropriate in length       Easy
# 26         NaN         NaN         NaN  Appropriate in length       Easy
# 28         Yes         Yes          No  Appropriate in length       Easy
#
#    ConvertedCompYearly
# 11            194400.0
# 12             65000.0
# 14            110000.0
# 26            106960.0
# 28            130000.0
#
# [5 rows x 79 columns]

# %% [markdown]
# Finally, to examine compensation, I need to use the column 'ConvertedCompYearly' which is the annual compensation for people who disclosed their compensation. Since some people provided compensation by month or week, it was adjusted in the dataset.
#
# In here, I will focus on data with converted yearly compensation in the US

# %%
# Out:
# <AxesSubplot:>

# %%
# Out:
# (8418, 79)

# %%
sns.boxplot(x='ConvertedCompYearly',
            data=df_dropna_targetUS)
# Out:
# <AxesSubplot:xlabel='ConvertedCompYearly'>

# %%
sns.boxplot(x='ConvertedCompYearly',
            data=df_dropna_targetUS)

# %% [markdown]
# Most of the compensation lie on the left side of the plot so I will remove the few very high compensation and consider them as outliers. From the boxplot, I will say over 2e7

# %%
sns.boxplot(x='ConvertedCompYearly',
            data=df_dropna_targetUS[df_dropna_targetUS['ConvertedCompYearly']<=0.2e7])
# Out:
# <AxesSubplot:xlabel='ConvertedCompYearly'>

# %%
#look at the histogram
df_dropna_targetUS[df_dropna_targetUS['ConvertedCompYearly']<=0.2e7]['ConvertedCompYearly'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df_dropna_targetUS[df_dropna_targetUS['ConvertedCompYearly']<=0.2e7].describe()
# Out:
#          ResponseId     CompTotal  VCHostingPersonal use  \
# count   9799.000000  9.799000e+03                    0.0
# mean   36462.400041  1.392258e+05                    NaN
# std    21021.696360  1.136552e+05                    NaN
# min       12.000000  1.000000e+00                    NaN
# 25%    16437.500000  8.500000e+04                    NaN
# 50%    39134.000000  1.292500e+05                    NaN
# 75%    53541.500000  1.750000e+05                    NaN
# max    73120.000000  2.000000e+06                    NaN
#
#        VCHostingProfessional use      WorkExp  ConvertedCompYearly
# count                        0.0  6874.000000         9.799000e+03
# mean                         NaN    12.877219         1.714767e+05
# std                          NaN     9.909281         2.073598e+05
# min                          NaN     0.000000         1.000000e+00
# 25%                          NaN     5.000000         9.000000e+04
# 50%                          NaN    10.000000         1.310000e+05
# 75%                          NaN    18.000000         1.800000e+05
# max                          NaN    50.000000         2.000000e+06

# %%
my_palette = {"GROUP_A": 'Greys', "GROUP_B": 'Reds', "GROUP_C": 'Blues', "GROUP_D": 'Greens'}

for ind, g in enumerate(groups):
    sns.swarmplot(x="group", y="value", data=data[data.group == g], order=groups,
                  palette=my_palette[g], hue="replicate")
    sns.swarmplot(x="group", y="value", data=avgs[avgs.group == g], order=groups,
                  size=8, palette=my_palette[g], hue="replicate", edgecolor="k", linewidth=2)

# plt.gca().legend_.remove() # optionally suppress the legend
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles=handles[:3], title='replicate')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dd/nb8m5vwd1sz3_s49jh1plcfr0000gn/T/ipykernel_85650/1110721603.py in <module>
# ----> 1 sns.boxplot(x='ConvertedCompYearly', groupby='Gender',data=df_dropna_targetUS[df_dropna_targetUS['ConvertedCompYearly']<=0.2e7])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2249     kwargs.update(dict(whis=whis))
#    2250
# -> 2251     plotter.plot(ax, kwargs)
#    2252     return ax
#    2253
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in plot(self, ax, boxplot_kws)
#     507     def plot(self, ax, boxplot_kws):
#     508         """Make the plot."""
# --> 509         self.draw_boxplot(ax, boxplot_kws)
#     510         self.annotate_axes(ax)
#     511         if self.orient == "h":
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in draw_boxplot(self, ax, kws)
#     439                     continue
#     440
# --> 441                 artist_dict = ax.boxplot(box_data,
#     442                                          vert=vert,
#     443                                          patch_artist=True,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: boxplot() got an unexpected keyword argument 'groupby'

# %%
other variables to look at
# Out:
# array([nan, 'Yearly', 'Monthly', 'Weekly'], dtype=object)

# %% [markdown]
# 'CodingActivities'
# 'DevType'
# 'PurchaseInfluence'
# 'BuyNewTool'
# 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'Blockchain', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm',
#        'TBranch', 'ICorPM',
#        'WorkExp'

# %%
df2022['MainBranch'].unique()
# Out:
# array(['None of these', 'I am a developer by profession',
#        'I am not primarily a developer, but I write code sometimes as part of my work',
#        'I code primarily as a hobby', 'I am learning to code',
#        'I used to be a developer by profession, but no longer am'],
#       dtype=object)

# %% [markdown]
# From a first overview of the headers, I want to keep the following columns for sure

# %%
df_keep=df2022['ConvertedCompYearly','Employment', 'RemoteWork','EdLevel', 'LearnCode', 'LearnCodeOnline','LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType','Country', 'Currency','CompTotal', 'CompFreq','Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity',
       'Accessibility', 'MentalHealth']

# %%
### My three main questions

# %%
# Data Preparation

# %%
## Selected features

# %%
## Missing data

# %%
# Modeling

# %%
# Evaluation

# %%
# Deployment

# %% [markdown]
# Resources used for this project:
# - https://medium.com/towards-data-science/crisp-dm-methodology-for-your-first-data-science-project-769f35e0346c
# - https://en.wikipedia.org/wiki/Cross-industry_standard_process_for_data_mining
